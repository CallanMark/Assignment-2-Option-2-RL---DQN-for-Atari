# %% [markdown]
# # CS4287 Assignment 2: Deep Reinforcement Learning (Atari)
#
# **Team Members:**
# * **Name:** Raid Mouras
# * **ID:** 22368566
# * **Name:** Jason Cushen
# * **ID:** 22342516
# * **Name:** Mark Callan
# * **ID:** 22363246

# %%
# --- CELL 1: INSTALL DEPENDENCIES ---
# %pip install gymnasium[atari] gymnasium[accept-rom-license] torch torchvision numpy opencv-python matplotlib ale-py
# !AutoROM --accept-license
# Out:
# Requirement already satisfied: torch in c:\users\raid\appdata\local\programs\python\python313\lib\site-packages (2.9.0+cu130)
# Requirement already satisfied: torchvision in c:\users\raid\appdata\local\programs\python\python313\lib\site-packages (0.24.0+cu130)
# Requirement already satisfied: numpy in c:\users\raid\appdata\local\programs\python\python313\lib\site-packages (2.2.6)
# Requirement already satisfied: opencv-python in c:\users\raid\appdata\local\programs\python\python313\lib\site-packages (4.12.0.88)
# Requirement already satisfied: matplotlib in c:\users\raid\appdata\local\programs\python\python313\lib\site-packages (3.10.6)
# Requirement already satisfied: ale-py in c:\users\raid\appdata\local\programs\python\python313\lib\site-packages (0.11.2)
# Requirement already satisfied: gymnasium[atari] in c:\users\raid\appdata\local\programs\python\python313\lib\site-packages (1.2.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\raid\appdata\local\programs\python\python313\lib\site-packages (from gymnasium[atari]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\raid\appdata\local\programs\python\python313\lib\site-packages (from gymnasium[atari]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\raid\appdata\local\programs\python\python313\lib\site-packages (from gymnasium[atari]) (0.0.4)
# Requirement already satisfied: filelock in c:\users\raid\appdata\local\programs\python\python313\lib\site-packages (from torch) (3.20.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\raid\appdata\local\programs\python\python313\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\raid\appdata\local\programs\python\python313\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\raid\appdata\local\programs\python\python313\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\raid\appdata\local\programs\python\python313\lib\site-packages (from torch) (2025.9.0)
# Requirement already satisfied: setuptools in c:\users\raid\appdata\local\programs\python\python313\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\raid\appdata\local\programs\python\python313\lib\site-packages (from torchvision) (11.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\raid\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\raid\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\raid\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\raid\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\raid\appdata\roaming\python\python313\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\raid\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\raid\appdata\roaming\python\python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\raid\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\raid\appdata\local\programs\python\python313\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\raid\appdata\local\programs\python\python313\lib\site-packages (from jinja2->torch) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: gymnasium 1.2.2 does not provide the extra 'accept-rom-license'
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# 'AutoROM' is not recognized as an internal or external command,
# operable program or batch file.

# %%
#cell 2
import gymnasium as gym
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
from collections import deque
import cv2
import time

# --- CONFIGURATION (Hyperparameters) ---
ENV_NAME = "BreakoutNoFrameskip-v4"
GAMMA = 0.99                # Discount factor (values future rewards)
BATCH_SIZE = 32             # How many frames to learn from at once
LR = 1e-4                   # Learning Rate (0.0001 is standard for Atari)
EPSILON_START = 1.0         # Start 100% random
EPSILON_FINAL = 0.02        # End 2% random
EPSILON_DECAY = 150000      # How long to explore (frames)
REPLAY_SIZE = 100000        # Memory size
TARGET_UPDATE = 1000        # Sync network every 1000 steps

# --- HARDWARE CHECK ---
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print("Setup Complete.")
if device.type == 'cuda':
    print(f"GPU DETECTED: {torch.cuda.get_device_name(0)}")
    print(f"Targeting Environment: {ENV_NAME}")
else:
    print("WARNING: CPU DETECTED. Training will be extremely slow.")
# Out:
# Setup Complete.
# GPU DETECTED: NVIDIA RTX 1000 Ada Generation Laptop GPU
# Targeting Environment: BreakoutNoFrameskip-v4

# %%
# --- CELL 3: PREPROCESSING ---

class AtariWrapper(gym.Wrapper):
    def __init__(self, env, k=4):
        super().__init__(env)
        self.k = k  # Stack 4 frames
        self.frames = deque([], maxlen=k)
        
        # Define what the AI sees: (4 stacked frames, 84 height, 84 width)
        self.observation_space = gym.spaces.Box(
            low=0, high=255, shape=(k, 84, 84), dtype=np.uint8
        )

    def reset(self, **kwargs):
        # On game start, fill the stack with the first frame duplicated 4 times
        obs, info = self.env.reset(**kwargs)
        processed_frame = self._process(obs)
        for _ in range(self.k):
            self.frames.append(processed_frame)
        return self._get_obs(), info

    def step(self, action):
        # Play one step, process the new frame, and add to stack
        obs, reward, terminated, truncated, info = self.env.step(action)
        self.frames.append(self._process(obs))
        return self._get_obs(), reward, terminated, truncated, info

    def _process(self, frame):
        # 1. Grayscale
        frame = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
        # 2. Resize to 84x84
        frame = cv2.resize(frame, (84, 84), interpolation=cv2.INTER_AREA)
        return frame

    def _get_obs(self):
        return np.array(self.frames)

print("Cell 3 Complete: Preprocessing wrapper defined.")
# Out:
# Cell 3 Complete: Preprocessing wrapper defined.

# %%
# --- CELL 4: THE NETWORK ---

class DQN(nn.Module):
    def __init__(self, input_shape, num_actions):
        super(DQN, self).__init__()
        
        # 1. Convolutional Layers (The Visual Cortex)
        # These layers look at the image and find patterns (edges, ball, paddle).
        self.features = nn.Sequential(
            # Conv 1: Sees big shapes. Input channels = 4 (stacked frames).
            nn.Conv2d(input_shape[0], 32, kernel_size=8, stride=4),
            nn.ReLU(),
            
            # Conv 2: Sees medium details.
            nn.Conv2d(32, 64, kernel_size=4, stride=2),
            nn.ReLU(),
            
            # Conv 3: Sees fine details.
            nn.Conv2d(64, 64, kernel_size=3, stride=1),
            nn.ReLU()
        )
        
        # 2. Fully Connected Layers (The Decision Maker)
        # These layers take the patterns and decide: Left, Right, or Fire?
        self.fc = nn.Sequential(
            nn.Linear(64 * 7 * 7, 512), # 3136 inputs -> 512 neurons
            nn.ReLU(),
            nn.Linear(512, num_actions) # Output: 1 score for each button
        )

    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1) # Flatten the image into a list of numbers
        return self.fc(x)

print("Cell 4 Complete: Network Architecture defined.")
# Out:
# Cell 4 Complete: Network Architecture defined.

# %%
# --- CELL 5: THE TRAINING LOOP (OPTIMIZED) ---

import ale_py
print(f"Atari Engine Loaded: {ale_py.__version__}")

# 1. Initialize the Game with STANDARD Frameskip
# frameskip=4 is crucial. It speeds up training by 4x and makes movement visible.
env = gym.make("ALE/Breakout-v5", frameskip=4, repeat_action_probability=0.0)
env = AtariWrapper(env) 

# 2. Initialize Networks
agent_net = DQN(env.observation_space.shape, env.action_space.n).to(device)
target_net = DQN(env.observation_space.shape, env.action_space.n).to(device)
target_net.load_state_dict(agent_net.state_dict()) 

optimizer = optim.Adam(agent_net.parameters(), lr=LR)

# SAFETY: If 100k memory crashes RAM, we catch it.
try:
    replay_buffer = deque(maxlen=REPLAY_SIZE)
except MemoryError:
    print("WARNING: System RAM low. Reducing Replay Buffer size to 50,000.")
    replay_buffer = deque(maxlen=50000)

steps = 0
rewards_history = []

print(f"TRAINING STARTED on {device}...")
print("Frameskip set to 4 (Standard Atari Speed).")

# 3. Training Loop
for episode in range(5000): 
    state, _ = env.reset()
    total_reward = 0
    done = False
    
    while not done:
        steps += 1
        
        # A. Epsilon Greedy
        epsilon = EPSILON_FINAL + (EPSILON_START - EPSILON_FINAL) * np.exp(-1. * steps / EPSILON_DECAY)
        
        if random.random() > epsilon:
            with torch.no_grad():
                state_t = torch.tensor(state, device=device, dtype=torch.float32).unsqueeze(0) / 255.0
                action = agent_net(state_t).argmax().item()
        else:
            action = env.action_space.sample()
            
        # B. Step
        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        
        # C. Save
        replay_buffer.append((state, action, reward, next_state, done))
        state = next_state
        total_reward += reward
        
        # D. Train
        if len(replay_buffer) > BATCH_SIZE:
            batch = random.sample(replay_buffer, BATCH_SIZE)
            states, actions, rewards, next_states, dones = zip(*batch)
            
            states = torch.tensor(np.array(states), device=device, dtype=torch.float32) / 255.0
            actions = torch.tensor(actions, device=device, dtype=torch.int64).unsqueeze(1)
            rewards = torch.tensor(rewards, device=device, dtype=torch.float32).unsqueeze(1)
            next_states = torch.tensor(np.array(next_states), device=device, dtype=torch.float32) / 255.0
            dones = torch.tensor(dones, device=device, dtype=torch.float32).unsqueeze(1)
            
            curr_q = agent_net(states).gather(1, actions)
            
            with torch.no_grad():
                max_next_q = target_net(next_states).max(1)[0].unsqueeze(1)
                target_q = rewards + (GAMMA * max_next_q * (1 - dones))
                
            loss = nn.SmoothL1Loss()(curr_q, target_q)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
        # E. Sync Target
        if steps % TARGET_UPDATE == 0:
            target_net.load_state_dict(agent_net.state_dict())

    rewards_history.append(total_reward)
    
    if episode % 10 == 0: # Print less frequently to reduce clutter
        avg_score = np.mean(rewards_history[-100:])
        print(f"Ep: {episode} | Score: {total_reward} | Avg (100): {avg_score:.2f} | Epsilon: {epsilon:.2f} | Steps: {steps}")

env.close()
print("DQN Training Finished.")
# Out:
# Atari Engine Loaded: 0.11.2
# TRAINING STARTED on cuda...
# Frameskip set to 4 (Standard Atari Speed).
# Ep: 0 | Score: 2.0 | Avg (100): 2.00 | Epsilon: 1.00 | Steps: 224
# Ep: 10 | Score: 0.0 | Avg (100): 0.55 | Epsilon: 0.99 | Steps: 1748
# Ep: 20 | Score: 0.0 | Avg (100): 0.71 | Epsilon: 0.98 | Steps: 3472
# Ep: 30 | Score: 0.0 | Avg (100): 0.74 | Epsilon: 0.97 | Steps: 5189
# Ep: 40 | Score: 1.0 | Avg (100): 0.80 | Epsilon: 0.96 | Steps: 6935
# Ep: 50 | Score: 0.0 | Avg (100): 0.86 | Epsilon: 0.94 | Steps: 8749
# Ep: 60 | Score: 4.0 | Avg (100): 0.93 | Epsilon: 0.93 | Steps: 10559
# Ep: 70 | Score: 2.0 | Avg (100): 0.94 | Epsilon: 0.92 | Steps: 12337
# Ep: 80 | Score: 4.0 | Avg (100): 0.96 | Epsilon: 0.91 | Steps: 14128
# Ep: 90 | Score: 0.0 | Avg (100): 0.95 | Epsilon: 0.90 | Steps: 15782
# Ep: 100 | Score: 2.0 | Avg (100): 1.01 | Epsilon: 0.89 | Steps: 17815
# Ep: 110 | Score: 2.0 | Avg (100): 1.06 | Epsilon: 0.88 | Steps: 19490
# Ep: 120 | Score: 4.0 | Avg (100): 1.10 | Epsilon: 0.87 | Steps: 21370
# Ep: 130 | Score: 4.0 | Avg (100): 1.21 | Epsilon: 0.86 | Steps: 23393
# Ep: 140 | Score: 4.0 | Avg (100): 1.31 | Epsilon: 0.85 | Steps: 25381
# Ep: 150 | Score: 2.0 | Avg (100): 1.35 | Epsilon: 0.84 | Steps: 27205
# Ep: 160 | Score: 3.0 | Avg (100): 1.51 | Epsilon: 0.82 | Steps: 29578
# Ep: 170 | Score: 7.0 | Avg (100): 1.75 | Epsilon: 0.81 | Steps: 32217
# Ep: 180 | Score: 3.0 | Avg (100): 1.88 | Epsilon: 0.80 | Steps: 34414
# Ep: 190 | Score: 1.0 | Avg (100): 2.02 | Epsilon: 0.79 | Steps: 36574
# Ep: 200 | Score: 2.0 | Avg (100): 2.12 | Epsilon: 0.78 | Steps: 38802
# Ep: 210 | Score: 5.0 | Avg (100): 2.37 | Epsilon: 0.76 | Steps: 41382
# Ep: 220 | Score: 3.0 | Avg (100): 2.56 | Epsilon: 0.75 | Steps: 43939
# Ep: 230 | Score: 3.0 | Avg (100): 2.60 | Epsilon: 0.74 | Steps: 46186
# Ep: 240 | Score: 2.0 | Avg (100): 2.69 | Epsilon: 0.73 | Steps: 48555
# Ep: 250 | Score: 2.0 | Avg (100): 2.74 | Epsilon: 0.72 | Steps: 50611
# Ep: 260 | Score: 4.0 | Avg (100): 2.76 | Epsilon: 0.71 | Steps: 53078
# Ep: 270 | Score: 1.0 | Avg (100): 2.71 | Epsilon: 0.70 | Steps: 55460
# Ep: 280 | Score: 2.0 | Avg (100): 2.80 | Epsilon: 0.69 | Steps: 57918
# Ep: 290 | Score: 4.0 | Avg (100): 2.81 | Epsilon: 0.68 | Steps: 60049
# Ep: 300 | Score: 8.0 | Avg (100): 2.87 | Epsilon: 0.67 | Steps: 62479
# Ep: 310 | Score: 2.0 | Avg (100): 2.95 | Epsilon: 0.66 | Steps: 65071
# Ep: 320 | Score: 2.0 | Avg (100): 2.89 | Epsilon: 0.65 | Steps: 67376
# Ep: 330 | Score: 2.0 | Avg (100): 3.06 | Epsilon: 0.63 | Steps: 70044
# Ep: 340 | Score: 4.0 | Avg (100): 3.07 | Epsilon: 0.62 | Steps: 72539
# Ep: 350 | Score: 5.0 | Avg (100): 3.24 | Epsilon: 0.61 | Steps: 75338
# Ep: 360 | Score: 1.0 | Avg (100): 3.30 | Epsilon: 0.60 | Steps: 78031
# Ep: 370 | Score: 2.0 | Avg (100): 3.40 | Epsilon: 0.59 | Steps: 80822
# Ep: 380 | Score: 4.0 | Avg (100): 3.56 | Epsilon: 0.58 | Steps: 84095
# Ep: 390 | Score: 5.0 | Avg (100): 3.81 | Epsilon: 0.57 | Steps: 87009
# Ep: 400 | Score: 4.0 | Avg (100): 3.86 | Epsilon: 0.56 | Steps: 89769
# Ep: 410 | Score: 7.0 | Avg (100): 3.83 | Epsilon: 0.55 | Steps: 92460
# Ep: 420 | Score: 5.0 | Avg (100): 4.07 | Epsilon: 0.54 | Steps: 95556
# Ep: 430 | Score: 4.0 | Avg (100): 4.07 | Epsilon: 0.53 | Steps: 98314
# Ep: 440 | Score: 4.0 | Avg (100): 4.31 | Epsilon: 0.52 | Steps: 101880
# Ep: 450 | Score: 4.0 | Avg (100): 4.61 | Epsilon: 0.51 | Steps: 105452
# Ep: 460 | Score: 4.0 | Avg (100): 4.76 | Epsilon: 0.50 | Steps: 108626
# Ep: 470 | Score: 4.0 | Avg (100): 4.87 | Epsilon: 0.49 | Steps: 111812
# Ep: 480 | Score: 10.0 | Avg (100): 4.97 | Epsilon: 0.47 | Steps: 115128
# Ep: 490 | Score: 8.0 | Avg (100): 5.13 | Epsilon: 0.46 | Steps: 118799
# Ep: 500 | Score: 7.0 | Avg (100): 5.47 | Epsilon: 0.45 | Steps: 123045
# Ep: 510 | Score: 11.0 | Avg (100): 6.03 | Epsilon: 0.44 | Steps: 127619
# Ep: 520 | Score: 3.0 | Avg (100): 6.23 | Epsilon: 0.43 | Steps: 131638
# Ep: 530 | Score: 6.0 | Avg (100): 6.69 | Epsilon: 0.42 | Steps: 135874
# Ep: 540 | Score: 5.0 | Avg (100): 7.18 | Epsilon: 0.40 | Steps: 140676
# Ep: 550 | Score: 9.0 | Avg (100): 7.36 | Epsilon: 0.39 | Steps: 144673
# Ep: 560 | Score: 13.0 | Avg (100): 7.82 | Epsilon: 0.38 | Steps: 148937
# Ep: 570 | Score: 14.0 | Avg (100): 8.44 | Epsilon: 0.37 | Steps: 153995
# Ep: 580 | Score: 8.0 | Avg (100): 8.96 | Epsilon: 0.36 | Steps: 159096
# Ep: 590 | Score: 16.0 | Avg (100): 9.54 | Epsilon: 0.35 | Steps: 164355
# Ep: 600 | Score: 7.0 | Avg (100): 9.79 | Epsilon: 0.34 | Steps: 168650
# Ep: 610 | Score: 16.0 | Avg (100): 10.12 | Epsilon: 0.33 | Steps: 173845
# Ep: 620 | Score: 11.0 | Avg (100): 10.52 | Epsilon: 0.32 | Steps: 178796
# Ep: 630 | Score: 14.0 | Avg (100): 10.67 | Epsilon: 0.31 | Steps: 183446
# Ep: 640 | Score: 10.0 | Avg (100): 10.89 | Epsilon: 0.30 | Steps: 188592
# Ep: 650 | Score: 7.0 | Avg (100): 10.95 | Epsilon: 0.29 | Steps: 192993
# Ep: 660 | Score: 13.0 | Avg (100): 11.13 | Epsilon: 0.28 | Steps: 197926
# Ep: 670 | Score: 18.0 | Avg (100): 11.40 | Epsilon: 0.27 | Steps: 203371
# Ep: 680 | Score: 6.0 | Avg (100): 11.63 | Epsilon: 0.26 | Steps: 208951
# Ep: 690 | Score: 19.0 | Avg (100): 11.85 | Epsilon: 0.25 | Steps: 214527
# Ep: 700 | Score: 9.0 | Avg (100): 11.99 | Epsilon: 0.25 | Steps: 219545
# Ep: 710 | Score: 13.0 | Avg (100): 12.25 | Epsilon: 0.24 | Steps: 224804
# Ep: 720 | Score: 10.0 | Avg (100): 12.60 | Epsilon: 0.23 | Steps: 230131
# Ep: 730 | Score: 8.0 | Avg (100): 12.80 | Epsilon: 0.23 | Steps: 234514
# Ep: 740 | Score: 14.0 | Avg (100): 12.67 | Epsilon: 0.22 | Steps: 238992
# Ep: 750 | Score: 12.0 | Avg (100): 13.14 | Epsilon: 0.21 | Steps: 244079
# Ep: 760 | Score: 23.0 | Avg (100): 13.33 | Epsilon: 0.21 | Steps: 249193
# Ep: 770 | Score: 11.0 | Avg (100): 13.23 | Epsilon: 0.20 | Steps: 253835
# Ep: 780 | Score: 10.0 | Avg (100): 12.96 | Epsilon: 0.20 | Steps: 258080
# Ep: 790 | Score: 14.0 | Avg (100): 12.74 | Epsilon: 0.19 | Steps: 262255
# Ep: 800 | Score: 15.0 | Avg (100): 12.99 | Epsilon: 0.19 | Steps: 266870
# Ep: 810 | Score: 16.0 | Avg (100): 12.68 | Epsilon: 0.18 | Steps: 271879
# Ep: 820 | Score: 14.0 | Avg (100): 12.48 | Epsilon: 0.17 | Steps: 276924
# Ep: 830 | Score: 9.0 | Avg (100): 12.59 | Epsilon: 0.17 | Steps: 281989
# Ep: 840 | Score: 8.0 | Avg (100): 12.66 | Epsilon: 0.17 | Steps: 286594
# Ep: 850 | Score: 7.0 | Avg (100): 12.41 | Epsilon: 0.16 | Steps: 291149
# Ep: 860 | Score: 18.0 | Avg (100): 11.98 | Epsilon: 0.16 | Steps: 295072
# Ep: 870 | Score: 7.0 | Avg (100): 11.95 | Epsilon: 0.15 | Steps: 299539
# Ep: 880 | Score: 6.0 | Avg (100): 11.89 | Epsilon: 0.15 | Steps: 303740
# Ep: 890 | Score: 6.0 | Avg (100): 11.59 | Epsilon: 0.15 | Steps: 307595
# Ep: 900 | Score: 15.0 | Avg (100): 11.43 | Epsilon: 0.14 | Steps: 311871
# Ep: 910 | Score: 7.0 | Avg (100): 11.51 | Epsilon: 0.14 | Steps: 316353
# Ep: 920 | Score: 14.0 | Avg (100): 11.22 | Epsilon: 0.14 | Steps: 320668
# Ep: 930 | Score: 14.0 | Avg (100): 11.15 | Epsilon: 0.13 | Steps: 325063
# Ep: 940 | Score: 11.0 | Avg (100): 11.40 | Epsilon: 0.13 | Steps: 329920
# Ep: 950 | Score: 14.0 | Avg (100): 11.44 | Epsilon: 0.13 | Steps: 334733
# Ep: 960 | Score: 14.0 | Avg (100): 11.78 | Epsilon: 0.12 | Steps: 339252
# Ep: 970 | Score: 15.0 | Avg (100): 12.02 | Epsilon: 0.12 | Steps: 344301
# Ep: 980 | Score: 15.0 | Avg (100): 12.34 | Epsilon: 0.12 | Steps: 349176
# Ep: 990 | Score: 19.0 | Avg (100): 12.83 | Epsilon: 0.11 | Steps: 354174
# Ep: 1000 | Score: 14.0 | Avg (100): 13.26 | Epsilon: 0.11 | Steps: 358902
# Ep: 1010 | Score: 9.0 | Avg (100): 12.91 | Epsilon: 0.11 | Steps: 362832
# Ep: 1020 | Score: 9.0 | Avg (100): 13.21 | Epsilon: 0.10 | Steps: 367424
# Ep: 1030 | Score: 13.0 | Avg (100): 13.47 | Epsilon: 0.10 | Steps: 372651
# Ep: 1040 | Score: 19.0 | Avg (100): 13.58 | Epsilon: 0.10 | Steps: 377642
# Ep: 1050 | Score: 5.0 | Avg (100): 14.05 | Epsilon: 0.10 | Steps: 382152
# Ep: 1060 | Score: 16.0 | Avg (100): 14.13 | Epsilon: 0.09 | Steps: 386742
# Ep: 1070 | Score: 11.0 | Avg (100): 14.18 | Epsilon: 0.09 | Steps: 391624
# Ep: 1080 | Score: 19.0 | Avg (100): 14.54 | Epsilon: 0.09 | Steps: 396494
# Ep: 1090 | Score: 11.0 | Avg (100): 14.79 | Epsilon: 0.09 | Steps: 401643
# Ep: 1100 | Score: 16.0 | Avg (100): 14.81 | Epsilon: 0.09 | Steps: 406667
# Ep: 1110 | Score: 8.0 | Avg (100): 15.62 | Epsilon: 0.08 | Steps: 411536
# Ep: 1120 | Score: 19.0 | Avg (100): 15.91 | Epsilon: 0.08 | Steps: 416135
# Ep: 1130 | Score: 4.0 | Avg (100): 16.03 | Epsilon: 0.08 | Steps: 420527
# Ep: 1140 | Score: 17.0 | Avg (100): 15.97 | Epsilon: 0.08 | Steps: 424898
# Ep: 1150 | Score: 19.0 | Avg (100): 15.86 | Epsilon: 0.08 | Steps: 429496
# Ep: 1160 | Score: 22.0 | Avg (100): 16.29 | Epsilon: 0.07 | Steps: 434426
# Ep: 1170 | Score: 22.0 | Avg (100): 15.99 | Epsilon: 0.07 | Steps: 438736
# Ep: 1180 | Score: 16.0 | Avg (100): 16.16 | Epsilon: 0.07 | Steps: 443930
# Ep: 1190 | Score: 12.0 | Avg (100): 16.12 | Epsilon: 0.07 | Steps: 448234
# Ep: 1200 | Score: 22.0 | Avg (100): 16.55 | Epsilon: 0.07 | Steps: 453022
# Ep: 1210 | Score: 12.0 | Avg (100): 16.28 | Epsilon: 0.07 | Steps: 457667
# Ep: 1220 | Score: 9.0 | Avg (100): 16.47 | Epsilon: 0.07 | Steps: 461917
# Ep: 1230 | Score: 13.0 | Avg (100): 16.67 | Epsilon: 0.06 | Steps: 466859
# Ep: 1240 | Score: 19.0 | Avg (100): 16.89 | Epsilon: 0.06 | Steps: 471244
# Ep: 1250 | Score: 22.0 | Avg (100): 17.37 | Epsilon: 0.06 | Steps: 476018
# Ep: 1260 | Score: 26.0 | Avg (100): 17.54 | Epsilon: 0.06 | Steps: 481093
# Ep: 1270 | Score: 14.0 | Avg (100): 18.11 | Epsilon: 0.06 | Steps: 485606
# Ep: 1280 | Score: 17.0 | Avg (100): 17.98 | Epsilon: 0.06 | Steps: 490031
# Ep: 1290 | Score: 20.0 | Avg (100): 18.12 | Epsilon: 0.06 | Steps: 494776
# Ep: 1300 | Score: 22.0 | Avg (100): 18.01 | Epsilon: 0.06 | Steps: 499508
# Ep: 1310 | Score: 16.0 | Avg (100): 18.41 | Epsilon: 0.05 | Steps: 504180
# Ep: 1320 | Score: 26.0 | Avg (100): 18.61 | Epsilon: 0.05 | Steps: 508480
# Ep: 1330 | Score: 19.0 | Avg (100): 18.59 | Epsilon: 0.05 | Steps: 513554
# Ep: 1340 | Score: 16.0 | Avg (100): 18.67 | Epsilon: 0.05 | Steps: 518405
# Ep: 1350 | Score: 13.0 | Avg (100): 18.40 | Epsilon: 0.05 | Steps: 522588
# Ep: 1360 | Score: 14.0 | Avg (100): 18.25 | Epsilon: 0.05 | Steps: 526946
# Ep: 1370 | Score: 24.0 | Avg (100): 18.47 | Epsilon: 0.05 | Steps: 531768
# Ep: 1380 | Score: 13.0 | Avg (100): 18.50 | Epsilon: 0.05 | Steps: 536301
# Ep: 1390 | Score: 15.0 | Avg (100): 18.64 | Epsilon: 0.05 | Steps: 540749
# Ep: 1400 | Score: 25.0 | Avg (100): 18.88 | Epsilon: 0.05 | Steps: 546124
# Ep: 1410 | Score: 22.0 | Avg (100): 19.06 | Epsilon: 0.04 | Steps: 550565
# Ep: 1420 | Score: 26.0 | Avg (100): 19.10 | Epsilon: 0.04 | Steps: 555471
# Ep: 1430 | Score: 24.0 | Avg (100): 19.48 | Epsilon: 0.04 | Steps: 560215
# Ep: 1440 | Score: 14.0 | Avg (100): 19.62 | Epsilon: 0.04 | Steps: 564605
# Ep: 1450 | Score: 26.0 | Avg (100): 19.96 | Epsilon: 0.04 | Steps: 569335
# Ep: 1460 | Score: 23.0 | Avg (100): 20.20 | Epsilon: 0.04 | Steps: 573826
# Ep: 1470 | Score: 20.0 | Avg (100): 20.13 | Epsilon: 0.04 | Steps: 578322
# Ep: 1480 | Score: 17.0 | Avg (100): 20.42 | Epsilon: 0.04 | Steps: 582874
# Ep: 1490 | Score: 30.0 | Avg (100): 20.41 | Epsilon: 0.04 | Steps: 587430
# Ep: 1500 | Score: 14.0 | Avg (100): 20.21 | Epsilon: 0.04 | Steps: 592435
# Ep: 1510 | Score: 21.0 | Avg (100): 20.48 | Epsilon: 0.04 | Steps: 597761
# Ep: 1520 | Score: 24.0 | Avg (100): 20.86 | Epsilon: 0.04 | Steps: 602950
# Ep: 1530 | Score: 11.0 | Avg (100): 20.72 | Epsilon: 0.04 | Steps: 607284
# Ep: 1540 | Score: 26.0 | Avg (100): 20.91 | Epsilon: 0.04 | Steps: 611690
# Ep: 1550 | Score: 18.0 | Avg (100): 20.75 | Epsilon: 0.04 | Steps: 615671
# Ep: 1560 | Score: 22.0 | Avg (100): 20.78 | Epsilon: 0.04 | Steps: 620268
# Ep: 1570 | Score: 22.0 | Avg (100): 21.12 | Epsilon: 0.04 | Steps: 624613
# Ep: 1580 | Score: 26.0 | Avg (100): 21.36 | Epsilon: 0.03 | Steps: 628750
# Ep: 1590 | Score: 23.0 | Avg (100): 21.68 | Epsilon: 0.03 | Steps: 632838
# Ep: 1600 | Score: 26.0 | Avg (100): 21.94 | Epsilon: 0.03 | Steps: 637003
# Ep: 1610 | Score: 22.0 | Avg (100): 21.83 | Epsilon: 0.03 | Steps: 641259
# Ep: 1620 | Score: 17.0 | Avg (100): 21.53 | Epsilon: 0.03 | Steps: 645269
# Ep: 1630 | Score: 26.0 | Avg (100): 21.54 | Epsilon: 0.03 | Steps: 649924
# Ep: 1640 | Score: 22.0 | Avg (100): 22.07 | Epsilon: 0.03 | Steps: 654334
# Ep: 1650 | Score: 23.0 | Avg (100): 22.47 | Epsilon: 0.03 | Steps: 658563
# Ep: 1660 | Score: 9.0 | Avg (100): 22.64 | Epsilon: 0.03 | Steps: 662997
# Ep: 1670 | Score: 22.0 | Avg (100): 22.55 | Epsilon: 0.03 | Steps: 667045
# Ep: 1680 | Score: 13.0 | Avg (100): 22.93 | Epsilon: 0.03 | Steps: 671415
# Ep: 1690 | Score: 32.0 | Avg (100): 23.48 | Epsilon: 0.03 | Steps: 675899
# Ep: 1700 | Score: 26.0 | Avg (100): 23.99 | Epsilon: 0.03 | Steps: 680520
# Ep: 1710 | Score: 29.0 | Avg (100): 24.49 | Epsilon: 0.03 | Steps: 685091
# Ep: 1720 | Score: 25.0 | Avg (100): 24.98 | Epsilon: 0.03 | Steps: 689675
# Ep: 1730 | Score: 27.0 | Avg (100): 25.85 | Epsilon: 0.03 | Steps: 694412
# Ep: 1740 | Score: 25.0 | Avg (100): 25.86 | Epsilon: 0.03 | Steps: 698759
# Ep: 1750 | Score: 25.0 | Avg (100): 26.74 | Epsilon: 0.03 | Steps: 704179
# Ep: 1760 | Score: 25.0 | Avg (100): 27.51 | Epsilon: 0.03 | Steps: 708762
# Ep: 1770 | Score: 21.0 | Avg (100): 28.05 | Epsilon: 0.03 | Steps: 713077
# Ep: 1780 | Score: 23.0 | Avg (100): 27.77 | Epsilon: 0.03 | Steps: 717646
# Ep: 1790 | Score: 17.0 | Avg (100): 27.67 | Epsilon: 0.03 | Steps: 722336
# Ep: 1800 | Score: 34.0 | Avg (100): 27.57 | Epsilon: 0.03 | Steps: 727156
# Ep: 1810 | Score: 34.0 | Avg (100): 27.81 | Epsilon: 0.03 | Steps: 731928
# Ep: 1820 | Score: 31.0 | Avg (100): 27.49 | Epsilon: 0.03 | Steps: 736732
# Ep: 1830 | Score: 27.0 | Avg (100): 27.34 | Epsilon: 0.03 | Steps: 741526
# Ep: 1840 | Score: 29.0 | Avg (100): 27.66 | Epsilon: 0.03 | Steps: 746248
# Ep: 1850 | Score: 27.0 | Avg (100): 26.89 | Epsilon: 0.03 | Steps: 750419
# Ep: 1860 | Score: 29.0 | Avg (100): 26.78 | Epsilon: 0.03 | Steps: 755164
# Ep: 1870 | Score: 32.0 | Avg (100): 27.25 | Epsilon: 0.03 | Steps: 759876
# Ep: 1880 | Score: 32.0 | Avg (100): 28.14 | Epsilon: 0.03 | Steps: 764596
# Ep: 1890 | Score: 29.0 | Avg (100): 28.83 | Epsilon: 0.03 | Steps: 769097
# Ep: 1900 | Score: 30.0 | Avg (100): 29.46 | Epsilon: 0.03 | Steps: 773697
# Ep: 1910 | Score: 25.0 | Avg (100): 29.91 | Epsilon: 0.03 | Steps: 778728
# Ep: 1920 | Score: 30.0 | Avg (100): 31.16 | Epsilon: 0.03 | Steps: 783282
# Ep: 1930 | Score: 62.0 | Avg (100): 32.99 | Epsilon: 0.03 | Steps: 788585
# Ep: 1940 | Score: 58.0 | Avg (100): 33.57 | Epsilon: 0.02 | Steps: 793324
# Ep: 1950 | Score: 59.0 | Avg (100): 35.30 | Epsilon: 0.02 | Steps: 798483
# Ep: 1960 | Score: 54.0 | Avg (100): 36.56 | Epsilon: 0.02 | Steps: 803660
# Ep: 1970 | Score: 62.0 | Avg (100): 39.94 | Epsilon: 0.02 | Steps: 808823
# Ep: 1980 | Score: 58.0 | Avg (100): 41.48 | Epsilon: 0.02 | Steps: 814219
# Ep: 1990 | Score: 59.0 | Avg (100): 42.18 | Epsilon: 0.02 | Steps: 819530
# Ep: 2000 | Score: 54.0 | Avg (100): 43.19 | Epsilon: 0.02 | Steps: 825013
# Ep: 2010 | Score: 72.0 | Avg (100): 44.37 | Epsilon: 0.02 | Steps: 830522
# Ep: 2020 | Score: 55.0 | Avg (100): 48.02 | Epsilon: 0.02 | Steps: 836175
# Ep: 2030 | Score: 28.0 | Avg (100): 48.25 | Epsilon: 0.02 | Steps: 841738
# Ep: 2040 | Score: 65.0 | Avg (100): 49.45 | Epsilon: 0.02 | Steps: 846980
# Ep: 2050 | Score: 20.0 | Avg (100): 49.76 | Epsilon: 0.02 | Steps: 852344
# Ep: 2060 | Score: 74.0 | Avg (100): 49.12 | Epsilon: 0.02 | Steps: 857193
# Ep: 2070 | Score: 51.0 | Avg (100): 50.35 | Epsilon: 0.02 | Steps: 862992
# Ep: 2080 | Score: 34.0 | Avg (100): 52.36 | Epsilon: 0.02 | Steps: 868438
# Ep: 2090 | Score: 47.0 | Avg (100): 61.16 | Epsilon: 0.02 | Steps: 874573
# Ep: 2100 | Score: 59.0 | Avg (100): 66.57 | Epsilon: 0.02 | Steps: 880335
# Ep: 2110 | Score: 22.0 | Avg (100): 67.50 | Epsilon: 0.02 | Steps: 885167
# Ep: 2120 | Score: 21.0 | Avg (100): 62.95 | Epsilon: 0.02 | Steps: 889117
# Ep: 2130 | Score: 297.0 | Avg (100): 67.74 | Epsilon: 0.02 | Steps: 895132
# Ep: 2140 | Score: 68.0 | Avg (100): 70.51 | Epsilon: 0.02 | Steps: 900829
# Ep: 2150 | Score: 28.0 | Avg (100): 69.65 | Epsilon: 0.02 | Steps: 905646
# Ep: 2160 | Score: 49.0 | Avg (100): 73.06 | Epsilon: 0.02 | Steps: 910984
# Ep: 2170 | Score: 27.0 | Avg (100): 69.39 | Epsilon: 0.02 | Steps: 917615
# Ep: 2180 | Score: 33.0 | Avg (100): 65.70 | Epsilon: 0.02 | Steps: 922281
# Ep: 2190 | Score: 58.0 | Avg (100): 60.11 | Epsilon: 0.02 | Steps: 927920
# Ep: 2200 | Score: 73.0 | Avg (100): 53.82 | Epsilon: 0.02 | Steps: 932523
# Ep: 2210 | Score: 32.0 | Avg (100): 52.17 | Epsilon: 0.02 | Steps: 937504
# Ep: 2220 | Score: 9.0 | Avg (100): 52.16 | Epsilon: 0.02 | Steps: 942049
# Ep: 2230 | Score: 31.0 | Avg (100): 51.31 | Epsilon: 0.02 | Steps: 947403
# Ep: 2240 | Score: 12.0 | Avg (100): 48.64 | Epsilon: 0.02 | Steps: 951909
# Ep: 2250 | Score: 43.0 | Avg (100): 47.49 | Epsilon: 0.02 | Steps: 956602
# Ep: 2260 | Score: 63.0 | Avg (100): 47.08 | Epsilon: 0.02 | Steps: 961966
# Ep: 2270 | Score: 314.0 | Avg (100): 54.47 | Epsilon: 0.02 | Steps: 967486
# Ep: 2280 | Score: 318.0 | Avg (100): 65.52 | Epsilon: 0.02 | Steps: 973119
# Ep: 2290 | Score: 6.0 | Avg (100): 69.76 | Epsilon: 0.02 | Steps: 978504
# Ep: 2300 | Score: 318.0 | Avg (100): 83.90 | Epsilon: 0.02 | Steps: 984874
# Ep: 2310 | Score: 318.0 | Avg (100): 94.80 | Epsilon: 0.02 | Steps: 990692
# Ep: 2320 | Score: 349.0 | Avg (100): 101.47 | Epsilon: 0.02 | Steps: 996324
# Ep: 2330 | Score: 32.0 | Avg (100): 113.74 | Epsilon: 0.02 | Steps: 1003014
# Ep: 2340 | Score: 16.0 | Avg (100): 123.12 | Epsilon: 0.02 | Steps: 1009328
# Ep: 2350 | Score: 349.0 | Avg (100): 132.05 | Epsilon: 0.02 | Steps: 1014397
# Ep: 2360 | Score: 318.0 | Avg (100): 143.74 | Epsilon: 0.02 | Steps: 1020932
# Ep: 2370 | Score: 318.0 | Avg (100): 153.50 | Epsilon: 0.02 | Steps: 1027846
# Ep: 2380 | Score: 6.0 | Avg (100): 157.31 | Epsilon: 0.02 | Steps: 1034193
# Ep: 2390 | Score: 38.0 | Avg (100): 160.12 | Epsilon: 0.02 | Steps: 1039672
# Ep: 2400 | Score: 2.0 | Avg (100): 150.62 | Epsilon: 0.02 | Steps: 1044290
# Ep: 2410 | Score: 26.0 | Avg (100): 137.37 | Epsilon: 0.02 | Steps: 1049433
# Ep: 2420 | Score: 30.0 | Avg (100): 136.20 | Epsilon: 0.02 | Steps: 1054117
# Ep: 2430 | Score: 318.0 | Avg (100): 136.46 | Epsilon: 0.02 | Steps: 1061197
# Ep: 2440 | Score: 320.0 | Avg (100): 136.63 | Epsilon: 0.02 | Steps: 1067202
# Ep: 2450 | Score: 326.0 | Avg (100): 143.59 | Epsilon: 0.02 | Steps: 1074694
# Ep: 2460 | Score: 27.0 | Avg (100): 143.75 | Epsilon: 0.02 | Steps: 1081271
# Ep: 2470 | Score: 8.0 | Avg (100): 133.95 | Epsilon: 0.02 | Steps: 1086845
# Ep: 2480 | Score: 32.0 | Avg (100): 131.35 | Epsilon: 0.02 | Steps: 1093013
# Ep: 2490 | Score: 20.0 | Avg (100): 132.24 | Epsilon: 0.02 | Steps: 1099167
# Ep: 2500 | Score: 14.0 | Avg (100): 139.89 | Epsilon: 0.02 | Steps: 1105569
# Ep: 2510 | Score: 1.0 | Avg (100): 153.65 | Epsilon: 0.02 | Steps: 1111548
# Ep: 2520 | Score: 14.0 | Avg (100): 163.28 | Epsilon: 0.02 | Steps: 1118403
# Ep: 2530 | Score: 21.0 | Avg (100): 154.26 | Epsilon: 0.02 | Steps: 1125320
# Ep: 2540 | Score: 29.0 | Avg (100): 157.31 | Epsilon: 0.02 | Steps: 1131276
# Ep: 2550 | Score: 318.0 | Avg (100): 160.47 | Epsilon: 0.02 | Steps: 1138239
# Ep: 2560 | Score: 318.0 | Avg (100): 165.59 | Epsilon: 0.02 | Steps: 1144930
# Ep: 2570 | Score: 8.0 | Avg (100): 181.66 | Epsilon: 0.02 | Steps: 1152611
# Ep: 2580 | Score: 349.0 | Avg (100): 187.59 | Epsilon: 0.02 | Steps: 1159478
# Ep: 2590 | Score: 30.0 | Avg (100): 191.13 | Epsilon: 0.02 | Steps: 1166122
# Ep: 2600 | Score: 12.0 | Avg (100): 183.46 | Epsilon: 0.02 | Steps: 1171706
# Ep: 2610 | Score: 349.0 | Avg (100): 192.59 | Epsilon: 0.02 | Steps: 1180121
# Ep: 2620 | Score: 349.0 | Avg (100): 194.29 | Epsilon: 0.02 | Steps: 1187211
# Ep: 2630 | Score: 22.0 | Avg (100): 204.08 | Epsilon: 0.02 | Steps: 1194514
# Ep: 2640 | Score: 18.0 | Avg (100): 211.61 | Epsilon: 0.02 | Steps: 1201849
# Ep: 2650 | Score: 349.0 | Avg (100): 217.30 | Epsilon: 0.02 | Steps: 1209306
# Ep: 2660 | Score: 349.0 | Avg (100): 212.20 | Epsilon: 0.02 | Steps: 1215670
# Ep: 2670 | Score: 49.0 | Avg (100): 194.79 | Epsilon: 0.02 | Steps: 1221494
# Ep: 2680 | Score: 6.0 | Avg (100): 195.25 | Epsilon: 0.02 | Steps: 1228440
# Ep: 2690 | Score: 349.0 | Avg (100): 194.73 | Epsilon: 0.02 | Steps: 1234505
# Ep: 2700 | Score: 33.0 | Avg (100): 199.26 | Epsilon: 0.02 | Steps: 1240240
# Ep: 2710 | Score: 350.0 | Avg (100): 202.92 | Epsilon: 0.02 | Steps: 1248163
# Ep: 2720 | Score: 350.0 | Avg (100): 198.53 | Epsilon: 0.02 | Steps: 1254169
# Ep: 2730 | Score: 31.0 | Avg (100): 189.59 | Epsilon: 0.02 | Steps: 1260112
# Ep: 2740 | Score: 349.0 | Avg (100): 184.01 | Epsilon: 0.02 | Steps: 1267494
# Ep: 2750 | Score: 350.0 | Avg (100): 175.45 | Epsilon: 0.02 | Steps: 1274004
# Ep: 2760 | Score: 350.0 | Avg (100): 175.81 | Epsilon: 0.02 | Steps: 1280690
# Ep: 2770 | Score: 349.0 | Avg (100): 184.07 | Epsilon: 0.02 | Steps: 1287022
# Ep: 2780 | Score: 349.0 | Avg (100): 187.25 | Epsilon: 0.02 | Steps: 1294479
# Ep: 2790 | Score: 350.0 | Avg (100): 194.32 | Epsilon: 0.02 | Steps: 1301940
# Ep: 2800 | Score: 349.0 | Avg (100): 207.07 | Epsilon: 0.02 | Steps: 1309592
# Ep: 2810 | Score: 30.0 | Avg (100): 191.26 | Epsilon: 0.02 | Steps: 1315188
# Ep: 2820 | Score: 349.0 | Avg (100): 201.45 | Epsilon: 0.02 | Steps: 1322735
# Ep: 2830 | Score: 29.0 | Avg (100): 193.74 | Epsilon: 0.02 | Steps: 1327022
# Ep: 2840 | Score: 350.0 | Avg (100): 193.14 | Epsilon: 0.02 | Steps: 1333650
# Ep: 2850 | Score: 59.0 | Avg (100): 200.33 | Epsilon: 0.02 | Steps: 1341484
# Ep: 2860 | Score: 49.0 | Avg (100): 191.99 | Epsilon: 0.02 | Steps: 1347317
# Ep: 2870 | Score: 22.0 | Avg (100): 189.57 | Epsilon: 0.02 | Steps: 1353610
# Ep: 2880 | Score: 349.0 | Avg (100): 192.77 | Epsilon: 0.02 | Steps: 1361906
# Ep: 2890 | Score: 349.0 | Avg (100): 188.81 | Epsilon: 0.02 | Steps: 1369024
# Ep: 2900 | Score: 55.0 | Avg (100): 179.58 | Epsilon: 0.02 | Steps: 1375372
# Ep: 2910 | Score: 350.0 | Avg (100): 186.92 | Epsilon: 0.02 | Steps: 1382325
# Ep: 2920 | Score: 9.0 | Avg (100): 182.78 | Epsilon: 0.02 | Steps: 1389213
# Ep: 2930 | Score: 350.0 | Avg (100): 196.25 | Epsilon: 0.02 | Steps: 1396075
# Ep: 2940 | Score: 29.0 | Avg (100): 190.15 | Epsilon: 0.02 | Steps: 1401962
# Ep: 2950 | Score: 56.0 | Avg (100): 179.83 | Epsilon: 0.02 | Steps: 1408076
# Ep: 2960 | Score: 48.0 | Avg (100): 194.84 | Epsilon: 0.02 | Steps: 1415917
# Ep: 2970 | Score: 349.0 | Avg (100): 197.77 | Epsilon: 0.02 | Steps: 1422837
# Ep: 2980 | Score: 349.0 | Avg (100): 191.76 | Epsilon: 0.02 | Steps: 1430457
# Ep: 2990 | Score: 22.0 | Avg (100): 182.78 | Epsilon: 0.02 | Steps: 1436124
# Ep: 3000 | Score: 3.0 | Avg (100): 187.98 | Epsilon: 0.02 | Steps: 1442841
# Ep: 3010 | Score: 350.0 | Avg (100): 196.39 | Epsilon: 0.02 | Steps: 1450681
# Ep: 3020 | Score: 349.0 | Avg (100): 200.26 | Epsilon: 0.02 | Steps: 1458101
# Ep: 3030 | Score: 16.0 | Avg (100): 185.99 | Epsilon: 0.02 | Steps: 1461901
# Ep: 3040 | Score: 350.0 | Avg (100): 194.97 | Epsilon: 0.02 | Steps: 1468846
# Ep: 3050 | Score: 349.0 | Avg (100): 200.13 | Epsilon: 0.02 | Steps: 1475382
# Ep: 3060 | Score: 349.0 | Avg (100): 199.70 | Epsilon: 0.02 | Steps: 1483104
# Ep: 3070 | Score: 345.0 | Avg (100): 193.39 | Epsilon: 0.02 | Steps: 1489264
# Ep: 3080 | Score: 29.0 | Avg (100): 186.95 | Epsilon: 0.02 | Steps: 1495243
# Ep: 3090 | Score: 41.0 | Avg (100): 193.27 | Epsilon: 0.02 | Steps: 1501712
# Ep: 3100 | Score: 31.0 | Avg (100): 190.64 | Epsilon: 0.02 | Steps: 1508274
# Ep: 3110 | Score: 26.0 | Avg (100): 178.16 | Epsilon: 0.02 | Steps: 1514491
# Ep: 3120 | Score: 24.0 | Avg (100): 172.49 | Epsilon: 0.02 | Steps: 1521310
# Ep: 3130 | Score: 29.0 | Avg (100): 196.03 | Epsilon: 0.02 | Steps: 1529211
# Ep: 3140 | Score: 48.0 | Avg (100): 196.53 | Epsilon: 0.02 | Steps: 1536665
# Ep: 3150 | Score: 29.0 | Avg (100): 201.07 | Epsilon: 0.02 | Steps: 1545031
# Ep: 3160 | Score: 349.0 | Avg (100): 191.36 | Epsilon: 0.02 | Steps: 1551684
# Ep: 3170 | Score: 349.0 | Avg (100): 200.56 | Epsilon: 0.02 | Steps: 1558854
# Ep: 3180 | Score: 350.0 | Avg (100): 199.45 | Epsilon: 0.02 | Steps: 1564432
# Ep: 3190 | Score: 31.0 | Avg (100): 192.98 | Epsilon: 0.02 | Steps: 1569924
# Ep: 3200 | Score: 25.0 | Avg (100): 196.02 | Epsilon: 0.02 | Steps: 1577054
# Ep: 3210 | Score: 34.0 | Avg (100): 202.80 | Epsilon: 0.02 | Steps: 1584411
# Ep: 3220 | Score: 7.0 | Avg (100): 194.98 | Epsilon: 0.02 | Steps: 1589270
# Ep: 3230 | Score: 350.0 | Avg (100): 181.65 | Epsilon: 0.02 | Steps: 1595315
# Ep: 3240 | Score: 41.0 | Avg (100): 174.98 | Epsilon: 0.02 | Steps: 1601504
# Ep: 3250 | Score: 14.0 | Avg (100): 178.16 | Epsilon: 0.02 | Steps: 1609534
# Ep: 3260 | Score: 350.0 | Avg (100): 181.25 | Epsilon: 0.02 | Steps: 1617064
# Ep: 3270 | Score: 349.0 | Avg (100): 178.15 | Epsilon: 0.02 | Steps: 1623675
# Ep: 3280 | Score: 370.0 | Avg (100): 182.75 | Epsilon: 0.02 | Steps: 1630351
# Ep: 3290 | Score: 350.0 | Avg (100): 190.10 | Epsilon: 0.02 | Steps: 1637274
# Ep: 3300 | Score: 347.0 | Avg (100): 187.56 | Epsilon: 0.02 | Steps: 1645753
# Ep: 3310 | Score: 350.0 | Avg (100): 188.85 | Epsilon: 0.02 | Steps: 1653554
# Ep: 3320 | Score: 378.0 | Avg (100): 200.21 | Epsilon: 0.02 | Steps: 1660947
# Ep: 3330 | Score: 318.0 | Avg (100): 208.03 | Epsilon: 0.02 | Steps: 1668371
# Ep: 3340 | Score: 349.0 | Avg (100): 221.44 | Epsilon: 0.02 | Steps: 1676552
# Ep: 3350 | Score: 350.0 | Avg (100): 207.85 | Epsilon: 0.02 | Steps: 1682463
# Ep: 3360 | Score: 376.0 | Avg (100): 214.52 | Epsilon: 0.02 | Steps: 1689978
# Ep: 3370 | Score: 349.0 | Avg (100): 217.84 | Epsilon: 0.02 | Steps: 1697110
# Ep: 3380 | Score: 6.0 | Avg (100): 220.82 | Epsilon: 0.02 | Steps: 1705186
# Ep: 3390 | Score: 23.0 | Avg (100): 216.55 | Epsilon: 0.02 | Steps: 1711506
# Ep: 3400 | Score: 347.0 | Avg (100): 209.78 | Epsilon: 0.02 | Steps: 1717335
# Ep: 3410 | Score: 384.0 | Avg (100): 214.98 | Epsilon: 0.02 | Steps: 1725595
# Ep: 3420 | Score: 384.0 | Avg (100): 207.98 | Epsilon: 0.02 | Steps: 1731709
# Ep: 3430 | Score: 366.0 | Avg (100): 217.42 | Epsilon: 0.02 | Steps: 1740739
# Ep: 3440 | Score: 29.0 | Avg (100): 217.90 | Epsilon: 0.02 | Steps: 1749279
# Ep: 3450 | Score: 318.0 | Avg (100): 224.76 | Epsilon: 0.02 | Steps: 1756453
# Ep: 3460 | Score: 23.0 | Avg (100): 220.01 | Epsilon: 0.02 | Steps: 1763241
# Ep: 3470 | Score: 41.0 | Avg (100): 207.16 | Epsilon: 0.02 | Steps: 1769458
# Ep: 3480 | Score: 6.0 | Avg (100): 206.34 | Epsilon: 0.02 | Steps: 1776063
# Ep: 3490 | Score: 370.0 | Avg (100): 223.71 | Epsilon: 0.02 | Steps: 1785223
# Ep: 3500 | Score: 376.0 | Avg (100): 230.08 | Epsilon: 0.02 | Steps: 1791534
# Ep: 3510 | Score: 347.0 | Avg (100): 227.11 | Epsilon: 0.02 | Steps: 1799362
# Ep: 3520 | Score: 19.0 | Avg (100): 230.88 | Epsilon: 0.02 | Steps: 1807220
# Ep: 3530 | Score: 350.0 | Avg (100): 227.25 | Epsilon: 0.02 | Steps: 1815265
# Ep: 3540 | Score: 5.0 | Avg (100): 220.71 | Epsilon: 0.02 | Steps: 1822742
# Ep: 3550 | Score: 370.0 | Avg (100): 227.79 | Epsilon: 0.02 | Steps: 1831439
# Ep: 3560 | Score: 30.0 | Avg (100): 231.16 | Epsilon: 0.02 | Steps: 1839333
# Ep: 3570 | Score: 23.0 | Avg (100): 247.70 | Epsilon: 0.02 | Steps: 1847137
# Ep: 3580 | Score: 370.0 | Avg (100): 246.37 | Epsilon: 0.02 | Steps: 1854299
# Ep: 3590 | Score: 17.0 | Avg (100): 237.24 | Epsilon: 0.02 | Steps: 1862083
# Ep: 3600 | Score: 22.0 | Avg (100): 231.40 | Epsilon: 0.02 | Steps: 1867969
# Ep: 3610 | Score: 16.0 | Avg (100): 228.58 | Epsilon: 0.02 | Steps: 1875381
# Ep: 3620 | Score: 350.0 | Avg (100): 228.29 | Epsilon: 0.02 | Steps: 1882351
# Ep: 3630 | Score: 370.0 | Avg (100): 219.05 | Epsilon: 0.02 | Steps: 1889115
# Ep: 3640 | Score: 370.0 | Avg (100): 215.97 | Epsilon: 0.02 | Steps: 1896149
# Ep: 3650 | Score: 34.0 | Avg (100): 203.70 | Epsilon: 0.02 | Steps: 1902689
# Ep: 3660 | Score: 370.0 | Avg (100): 200.93 | Epsilon: 0.02 | Steps: 1909698
# Ep: 3670 | Score: 370.0 | Avg (100): 198.70 | Epsilon: 0.02 | Steps: 1917621
# Ep: 3680 | Score: 370.0 | Avg (100): 204.86 | Epsilon: 0.02 | Steps: 1925731
# Ep: 3690 | Score: 370.0 | Avg (100): 204.56 | Epsilon: 0.02 | Steps: 1933632
# Ep: 3700 | Score: 370.0 | Avg (100): 210.54 | Epsilon: 0.02 | Steps: 1940678
# Ep: 3710 | Score: 350.0 | Avg (100): 218.45 | Epsilon: 0.02 | Steps: 1949489
# Ep: 3720 | Score: 3.0 | Avg (100): 206.80 | Epsilon: 0.02 | Steps: 1954211
# Ep: 3730 | Score: 57.0 | Avg (100): 193.59 | Epsilon: 0.02 | Steps: 1958581
# Ep: 3740 | Score: 374.0 | Avg (100): 190.00 | Epsilon: 0.02 | Steps: 1965577
# Ep: 3750 | Score: 17.0 | Avg (100): 196.50 | Epsilon: 0.02 | Steps: 1974479
# Ep: 3760 | Score: 26.0 | Avg (100): 195.82 | Epsilon: 0.02 | Steps: 1981726
# Ep: 3770 | Score: 370.0 | Avg (100): 191.56 | Epsilon: 0.02 | Steps: 1988479
# Ep: 3780 | Score: 349.0 | Avg (100): 190.53 | Epsilon: 0.02 | Steps: 1996081
# Ep: 3790 | Score: 378.0 | Avg (100): 183.29 | Epsilon: 0.02 | Steps: 2002337
# Ep: 3800 | Score: 370.0 | Avg (100): 184.38 | Epsilon: 0.02 | Steps: 2010270
# Ep: 3810 | Score: 16.0 | Avg (100): 176.37 | Epsilon: 0.02 | Steps: 2018005
# Ep: 3820 | Score: 31.0 | Avg (100): 191.74 | Epsilon: 0.02 | Steps: 2025544
# Ep: 3830 | Score: 370.0 | Avg (100): 208.20 | Epsilon: 0.02 | Steps: 2033519
# Ep: 3840 | Score: 370.0 | Avg (100): 215.26 | Epsilon: 0.02 | Steps: 2041130
# Ep: 3850 | Score: 25.0 | Avg (100): 212.03 | Epsilon: 0.02 | Steps: 2048332
# Ep: 3860 | Score: 44.0 | Avg (100): 205.27 | Epsilon: 0.02 | Steps: 2054558
# Ep: 3870 | Score: 30.0 | Avg (100): 212.78 | Epsilon: 0.02 | Steps: 2062908
# Ep: 3880 | Score: 350.0 | Avg (100): 203.63 | Epsilon: 0.02 | Steps: 2069149
# Ep: 3890 | Score: 23.0 | Avg (100): 210.80 | Epsilon: 0.02 | Steps: 2076672
# Ep: 3900 | Score: 362.0 | Avg (100): 203.53 | Epsilon: 0.02 | Steps: 2082707
# Ep: 3910 | Score: 10.0 | Avg (100): 193.57 | Epsilon: 0.02 | Steps: 2088604
# Ep: 3920 | Score: 31.0 | Avg (100): 190.50 | Epsilon: 0.02 | Steps: 2096032
# Ep: 3930 | Score: 370.0 | Avg (100): 191.30 | Epsilon: 0.02 | Steps: 2103889
# Ep: 3940 | Score: 374.0 | Avg (100): 194.70 | Epsilon: 0.02 | Steps: 2112058
# Ep: 3950 | Score: 370.0 | Avg (100): 194.83 | Epsilon: 0.02 | Steps: 2120244
# Ep: 3960 | Score: 374.0 | Avg (100): 201.25 | Epsilon: 0.02 | Steps: 2127382
# Ep: 3970 | Score: 23.0 | Avg (100): 193.87 | Epsilon: 0.02 | Steps: 2134446
# Ep: 3980 | Score: 374.0 | Avg (100): 204.32 | Epsilon: 0.02 | Steps: 2142708
# Ep: 3990 | Score: 327.0 | Avg (100): 207.75 | Epsilon: 0.02 | Steps: 2151803
# Ep: 4000 | Score: 12.0 | Avg (100): 214.92 | Epsilon: 0.02 | Steps: 2159353
# Ep: 4010 | Score: 328.0 | Avg (100): 221.37 | Epsilon: 0.02 | Steps: 2166895
# Ep: 4020 | Score: 2.0 | Avg (100): 217.33 | Epsilon: 0.02 | Steps: 2174303
# Ep: 4030 | Score: 351.0 | Avg (100): 212.37 | Epsilon: 0.02 | Steps: 2180966
# Ep: 4040 | Score: 32.0 | Avg (100): 201.09 | Epsilon: 0.02 | Steps: 2187886
# Ep: 4050 | Score: 367.0 | Avg (100): 208.04 | Epsilon: 0.02 | Steps: 2196182
# Ep: 4060 | Score: 16.0 | Avg (100): 211.61 | Epsilon: 0.02 | Steps: 2203810
# Ep: 4070 | Score: 350.0 | Avg (100): 217.47 | Epsilon: 0.02 | Steps: 2211147
# Ep: 4080 | Score: 1.0 | Avg (100): 202.89 | Epsilon: 0.02 | Steps: 2216725
# Ep: 4090 | Score: 12.0 | Avg (100): 195.51 | Epsilon: 0.02 | Steps: 2224343
# Ep: 4100 | Score: 370.0 | Avg (100): 191.25 | Epsilon: 0.02 | Steps: 2231093
# Ep: 4110 | Score: 8.0 | Avg (100): 199.02 | Epsilon: 0.02 | Steps: 2239332
# Ep: 4120 | Score: 327.0 | Avg (100): 209.10 | Epsilon: 0.02 | Steps: 2247441
# Ep: 4130 | Score: 36.0 | Avg (100): 214.00 | Epsilon: 0.02 | Steps: 2255233
# Ep: 4140 | Score: 370.0 | Avg (100): 221.45 | Epsilon: 0.02 | Steps: 2262854
# Ep: 4150 | Score: 349.0 | Avg (100): 220.49 | Epsilon: 0.02 | Steps: 2270712
# Ep: 4160 | Score: 374.0 | Avg (100): 216.37 | Epsilon: 0.02 | Steps: 2277985
# Ep: 4170 | Score: 370.0 | Avg (100): 214.00 | Epsilon: 0.02 | Steps: 2285658
# Ep: 4180 | Score: 352.0 | Avg (100): 225.01 | Epsilon: 0.02 | Steps: 2293714
# Ep: 4190 | Score: 350.0 | Avg (100): 221.63 | Epsilon: 0.02 | Steps: 2299878
# Ep: 4200 | Score: 25.0 | Avg (100): 219.10 | Epsilon: 0.02 | Steps: 2306614
# Ep: 4210 | Score: 27.0 | Avg (100): 211.44 | Epsilon: 0.02 | Steps: 2313948
# Ep: 4220 | Score: 28.0 | Avg (100): 204.57 | Epsilon: 0.02 | Steps: 2320826
# Ep: 4230 | Score: 28.0 | Avg (100): 203.80 | Epsilon: 0.02 | Steps: 2328484
# Ep: 4240 | Score: 49.0 | Avg (100): 211.51 | Epsilon: 0.02 | Steps: 2337456
# Ep: 4250 | Score: 3.0 | Avg (100): 201.81 | Epsilon: 0.02 | Steps: 2343793
# Ep: 4260 | Score: 24.0 | Avg (100): 195.53 | Epsilon: 0.02 | Steps: 2350808
# Ep: 4270 | Score: 374.0 | Avg (100): 192.93 | Epsilon: 0.02 | Steps: 2358112
# Ep: 4280 | Score: 14.0 | Avg (100): 182.90 | Epsilon: 0.02 | Steps: 2364663
# Ep: 4290 | Score: 9.0 | Avg (100): 175.68 | Epsilon: 0.02 | Steps: 2370372
# Ep: 4300 | Score: 374.0 | Avg (100): 196.32 | Epsilon: 0.02 | Steps: 2379874
# Ep: 4310 | Score: 374.0 | Avg (100): 190.05 | Epsilon: 0.02 | Steps: 2385844
# Ep: 4320 | Score: 374.0 | Avg (100): 194.42 | Epsilon: 0.02 | Steps: 2393660
# Ep: 4330 | Score: 21.0 | Avg (100): 188.76 | Epsilon: 0.02 | Steps: 2400443
# Ep: 4340 | Score: 374.0 | Avg (100): 185.04 | Epsilon: 0.02 | Steps: 2408634
# Ep: 4350 | Score: 376.0 | Avg (100): 188.81 | Epsilon: 0.02 | Steps: 2415979
# Ep: 4360 | Score: 3.0 | Avg (100): 198.68 | Epsilon: 0.02 | Steps: 2423172
# Ep: 4370 | Score: 374.0 | Avg (100): 201.89 | Epsilon: 0.02 | Steps: 2431152
# Ep: 4380 | Score: 344.0 | Avg (100): 208.72 | Epsilon: 0.02 | Steps: 2439232
# Ep: 4390 | Score: 376.0 | Avg (100): 223.34 | Epsilon: 0.02 | Steps: 2447326
# Ep: 4400 | Score: 18.0 | Avg (100): 212.84 | Epsilon: 0.02 | Steps: 2454951
# Ep: 4410 | Score: 28.0 | Avg (100): 213.28 | Epsilon: 0.02 | Steps: 2461494
# Ep: 4420 | Score: 374.0 | Avg (100): 208.66 | Epsilon: 0.02 | Steps: 2467897
# Ep: 4430 | Score: 374.0 | Avg (100): 218.46 | Epsilon: 0.02 | Steps: 2476369
# Ep: 4440 | Score: 327.0 | Avg (100): 211.08 | Epsilon: 0.02 | Steps: 2483227
# Ep: 4450 | Score: 374.0 | Avg (100): 213.67 | Epsilon: 0.02 | Steps: 2490233
# Ep: 4460 | Score: 349.0 | Avg (100): 213.39 | Epsilon: 0.02 | Steps: 2498107
# Ep: 4470 | Score: 374.0 | Avg (100): 205.89 | Epsilon: 0.02 | Steps: 2504288
# Ep: 4480 | Score: 374.0 | Avg (100): 202.44 | Epsilon: 0.02 | Steps: 2510666
# Ep: 4490 | Score: 8.0 | Avg (100): 191.99 | Epsilon: 0.02 | Steps: 2517365
# Ep: 4500 | Score: 374.0 | Avg (100): 181.54 | Epsilon: 0.02 | Steps: 2523369
# Ep: 4510 | Score: 374.0 | Avg (100): 198.14 | Epsilon: 0.02 | Steps: 2532353
# Ep: 4520 | Score: 374.0 | Avg (100): 212.21 | Epsilon: 0.02 | Steps: 2541350
# Ep: 4530 | Score: 374.0 | Avg (100): 198.19 | Epsilon: 0.02 | Steps: 2547885
# Ep: 4540 | Score: 18.0 | Avg (100): 194.36 | Epsilon: 0.02 | Steps: 2553944
# Ep: 4550 | Score: 374.0 | Avg (100): 204.60 | Epsilon: 0.02 | Steps: 2562941
# Ep: 4560 | Score: 374.0 | Avg (100): 205.58 | Epsilon: 0.02 | Steps: 2570708
# Ep: 4570 | Score: 31.0 | Avg (100): 201.28 | Epsilon: 0.02 | Steps: 2576031
# Ep: 4580 | Score: 350.0 | Avg (100): 196.85 | Epsilon: 0.02 | Steps: 2581295
# Ep: 4590 | Score: 5.0 | Avg (100): 211.01 | Epsilon: 0.02 | Steps: 2589559
# Ep: 4600 | Score: 22.0 | Avg (100): 221.48 | Epsilon: 0.02 | Steps: 2597422
# Ep: 4610 | Score: 375.0 | Avg (100): 212.08 | Epsilon: 0.02 | Steps: 2604872
# Ep: 4620 | Score: 350.0 | Avg (100): 194.33 | Epsilon: 0.02 | Steps: 2610759
# Ep: 4630 | Score: 370.0 | Avg (100): 207.79 | Epsilon: 0.02 | Steps: 2618512
# Ep: 4640 | Score: 351.0 | Avg (100): 217.65 | Epsilon: 0.02 | Steps: 2626310
# Ep: 4650 | Score: 13.0 | Avg (100): 200.64 | Epsilon: 0.02 | Steps: 2632780
# Ep: 4660 | Score: 351.0 | Avg (100): 203.43 | Epsilon: 0.02 | Steps: 2641108
# Ep: 4670 | Score: 374.0 | Avg (100): 218.75 | Epsilon: 0.02 | Steps: 2650142
# Ep: 4680 | Score: 18.0 | Avg (100): 226.36 | Epsilon: 0.02 | Steps: 2657031
# Ep: 4690 | Score: 318.0 | Avg (100): 222.83 | Epsilon: 0.02 | Steps: 2664537
# Ep: 4700 | Score: 347.0 | Avg (100): 216.44 | Epsilon: 0.02 | Steps: 2671989
# Ep: 4710 | Score: 8.0 | Avg (100): 211.71 | Epsilon: 0.02 | Steps: 2678274
# Ep: 4720 | Score: 375.0 | Avg (100): 216.69 | Epsilon: 0.02 | Steps: 2685726
# Ep: 4730 | Score: 350.0 | Avg (100): 210.89 | Epsilon: 0.02 | Steps: 2693832
# Ep: 4740 | Score: 374.0 | Avg (100): 202.26 | Epsilon: 0.02 | Steps: 2700530
# Ep: 4750 | Score: 3.0 | Avg (100): 212.86 | Epsilon: 0.02 | Steps: 2708506
# Ep: 4760 | Score: 4.0 | Avg (100): 202.39 | Epsilon: 0.02 | Steps: 2714705
# Ep: 4770 | Score: 1.0 | Avg (100): 184.25 | Epsilon: 0.02 | Steps: 2719505
# Ep: 4780 | Score: 374.0 | Avg (100): 187.74 | Epsilon: 0.02 | Steps: 2727570
# Ep: 4790 | Score: 318.0 | Avg (100): 182.89 | Epsilon: 0.02 | Steps: 2733985
# Ep: 4800 | Score: 374.0 | Avg (100): 188.82 | Epsilon: 0.02 | Steps: 2741336
# Ep: 4810 | Score: 318.0 | Avg (100): 195.65 | Epsilon: 0.02 | Steps: 2748820
# Ep: 4820 | Score: 374.0 | Avg (100): 188.13 | Epsilon: 0.02 | Steps: 2755445
# Ep: 4830 | Score: 17.0 | Avg (100): 177.24 | Epsilon: 0.02 | Steps: 2761040
# Ep: 4840 | Score: 3.0 | Avg (100): 172.88 | Epsilon: 0.02 | Steps: 2766721
# Ep: 4850 | Score: 22.0 | Avg (100): 165.56 | Epsilon: 0.02 | Steps: 2773383
# Ep: 4860 | Score: 349.0 | Avg (100): 169.54 | Epsilon: 0.02 | Steps: 2780716
# Ep: 4870 | Score: 374.0 | Avg (100): 179.51 | Epsilon: 0.02 | Steps: 2787193
# Ep: 4880 | Score: 24.0 | Avg (100): 166.60 | Epsilon: 0.02 | Steps: 2792924
# Ep: 4890 | Score: 13.0 | Avg (100): 174.30 | Epsilon: 0.02 | Steps: 2800879
# Ep: 4900 | Score: 376.0 | Avg (100): 178.17 | Epsilon: 0.02 | Steps: 2809182
# Ep: 4910 | Score: 349.0 | Avg (100): 171.39 | Epsilon: 0.02 | Steps: 2815411
# Ep: 4920 | Score: 29.0 | Avg (100): 178.79 | Epsilon: 0.02 | Steps: 2822437
# Ep: 4930 | Score: 374.0 | Avg (100): 189.37 | Epsilon: 0.02 | Steps: 2830211
# Ep: 4940 | Score: 374.0 | Avg (100): 203.23 | Epsilon: 0.02 | Steps: 2838180
# Ep: 4950 | Score: 374.0 | Avg (100): 209.45 | Epsilon: 0.02 | Steps: 2845685
# Ep: 4960 | Score: 33.0 | Avg (100): 205.93 | Epsilon: 0.02 | Steps: 2852207
# Ep: 4970 | Score: 318.0 | Avg (100): 213.39 | Epsilon: 0.02 | Steps: 2860212
# Ep: 4980 | Score: 28.0 | Avg (100): 219.62 | Epsilon: 0.02 | Steps: 2867409
# Ep: 4990 | Score: 374.0 | Avg (100): 212.91 | Epsilon: 0.02 | Steps: 2875350
# DQN Training Finished.

# %%
# --- CELL 6: SAVE RESULTS, PLOT & STATS ---
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# 1. Save the Trained "Brain"
torch.save(agent_net.state_dict(), "breakout_model_v1.pth")
print("Model saved as 'breakout_model_v1.pth'")

# 2. Plot the Learning Curve
plt.figure(figsize=(10, 5))
plt.plot(rewards_history, label='Raw Score', alpha=0.3, color='cyan')

# Calculate a smooth trend line (Moving Average)
window_size = 50
if len(rewards_history) >= window_size:
    moving_avg = np.convolve(rewards_history, np.ones(window_size)/window_size, mode='valid')
    plt.plot(range(window_size-1, len(rewards_history)), moving_avg, label=f'{window_size}-Game Average', color='blue', linewidth=2)

plt.title("DQN Learning Progress (Breakout)")
plt.xlabel("Episode")
plt.ylabel("Score (Bricks Broken)")
plt.legend()
plt.grid(True, alpha=0.3)

# Save the plot
plt.savefig("learning_curve.png")
print("Graph saved as 'learning_curve.png'")
plt.show()

# 3. Statistical Analysis
# Calculate the Hard Statistics
best_score = np.max(rewards_history)
best_episode = np.argmax(rewards_history)
worst_score = np.min(rewards_history)
worst_episode = np.argmin(rewards_history)
mean_score = np.mean(rewards_history)      # Lifetime Average
median_score = np.median(rewards_history)
final_100_avg = np.mean(rewards_history[-100:]) # Current Skill

# Percentage Increase (Last 50 games vs First 50 games)
first_50_avg = np.mean(rewards_history[:50])
last_50_avg = np.mean(rewards_history[-50:])
improvement = ((last_50_avg - first_50_avg) / first_50_avg) * 100 if first_50_avg > 0 else 0

# Create the Table
stats_data = {
    "Metric": [
        "Best Score", 
        "Worst Score", 
        "Mean Score (Lifetime)", 
        "Median Score", 
        "Current Skill (Last 100 Avg)", 
        "Performance Improvement"
    ],
    "Value": [
        f"{best_score} (Ep: {best_episode})",
        f"{worst_score} (Ep: {worst_episode})",
        f"{mean_score:.2f}",
        f"{median_score:.2f}",
        f"{final_100_avg:.2f}",
        f"+{improvement:.1f}%"
    ]
}

df_stats = pd.DataFrame(stats_data)

# 4. Display the Table & Explanation
print("\n--- TRAINING SUMMARY STATISTICS ---")
display(df_stats)
# Out:
# Model saved as 'breakout_model_v1.pth'
# Graph saved as 'learning_curve.png'
# --- TRAINING SUMMARY STATISTICS ---
#                          Metric             Value
# 0                    Best Score  403.0 (Ep: 3576)
# 1                   Worst Score       0.0 (Ep: 1)
# 2         Mean Score (Lifetime)            116.65
# 3                  Median Score             26.00
# 4  Current Skill (Last 100 Avg)            209.71
# 5       Performance Improvement         +23065.9%

# %% [markdown]
# ## 7.2. Results Analysis
#
# The plot above illustrates the training progress over 2000 episodes.
#
# **1. Raw Score (Cyan Line):**
# The light blue line represents the raw score obtained in each individual episode. As expected in Atari environments, this metric is highly volatile. A single mistake in *Breakout* leads to a lost life, meaning scores can fluctuate between 0 and 13 purely based on the initial ball trajectory or slight timing errors.
#
# **2. 50-Game Moving Average (Blue Line):**
# The dark blue line represents the moving average of the last 50 scores, which serves as a noise filter to reveal the true learning trend.
# * **Phase 1 (Episodes 0–200):** The curve remains flat around a score of 1.0–1.5. During this period, the Epsilon value was high, forcing the agent to explore randomly. The agent was merely hitting the ball by chance.
# * **Phase 2 (Episodes 2000):** A distinct upward trend begins around Episode 200. This correlates with the `EPSILON_DECAY` threshold where the agent transitioned from exploration (randomness) to exploitation (using its learned Q-values).
# * **Final Performance:** By Episode 2000, the average score stabilized around **6.0**, with peak raw scores reaching **13.0**.
#
# **Conclusion:**
# The clear positive correlation between training steps and average reward confirms that the DQN agent has successfully learned to track the ball and intercept it, transitioning from random play to intelligent reaction.

# %%
# --- CELL 8: DOUBLE DQN (DDQN) EXPERIMENT ---

import ale_py
print(f"Atari Engine Loaded: {ale_py.__version__}")

# 1. Initialize with CORRECT Frameskip (4)
env = gym.make("ALE/Breakout-v5", frameskip=4, repeat_action_probability=0.0)
env = AtariWrapper(env) 

print("STARTING DOUBLE DQN (DDQN) EXPERIMENT (5000 Episodes)...")
ddqn_agent = DQN(env.observation_space.shape, env.action_space.n).to(device)
ddqn_target = DQN(env.observation_space.shape, env.action_space.n).to(device)
ddqn_target.load_state_dict(ddqn_agent.state_dict())
optimizer_ddqn = optim.Adam(ddqn_agent.parameters(), lr=LR)
replay_buffer_ddqn = deque(maxlen=REPLAY_SIZE)

steps = 0
ddqn_scores = []

for episode in range(5000): 
    state, _ = env.reset()
    total_reward = 0
    done = False
    
    while not done:
        steps += 1
        
        # A. Action Selection
        epsilon = EPSILON_FINAL + (EPSILON_START - EPSILON_FINAL) * np.exp(-1. * steps / EPSILON_DECAY)
        if random.random() > epsilon:
            with torch.no_grad():
                state_t = torch.tensor(state, device=device, dtype=torch.float32).unsqueeze(0) / 255.0
                action = ddqn_agent(state_t).argmax().item()
        else:
            action = env.action_space.sample()
            
        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        replay_buffer_ddqn.append((state, action, reward, next_state, done))
        state = next_state
        total_reward += reward
        
        # B. DDQN Update
        if len(replay_buffer_ddqn) > BATCH_SIZE:
            batch = random.sample(replay_buffer_ddqn, BATCH_SIZE)
            states, actions, rewards, next_states, dones = zip(*batch)
            
            states = torch.tensor(np.array(states), device=device, dtype=torch.float32) / 255.0
            actions = torch.tensor(actions, device=device, dtype=torch.int64).unsqueeze(1)
            rewards = torch.tensor(rewards, device=device, dtype=torch.float32).unsqueeze(1)
            next_states = torch.tensor(np.array(next_states), device=device, dtype=torch.float32) / 255.0
            dones = torch.tensor(dones, device=device, dtype=torch.float32).unsqueeze(1)
            
            # 1. Actor selects best action
            best_actions = ddqn_agent(next_states).argmax(1).unsqueeze(1)
            # 2. Critic evaluates that action
            with torch.no_grad():
                target_q_values = ddqn_target(next_states).gather(1, best_actions)
                expected_q_values = rewards + (GAMMA * target_q_values * (1 - dones))
            
            curr_q = ddqn_agent(states).gather(1, actions)
            loss = nn.SmoothL1Loss()(curr_q, expected_q_values)
            optimizer_ddqn.zero_grad()
            loss.backward()
            optimizer_ddqn.step()
            
        if steps % TARGET_UPDATE == 0:
            ddqn_target.load_state_dict(ddqn_agent.state_dict())

    ddqn_scores.append(total_reward)
    
    # --- UPDATED PRINT STATEMENT ---
    if episode % 10 == 0:
        avg_score = np.mean(ddqn_scores[-100:])
        print(f"DDQN Ep: {episode} | Score: {total_reward} | Avg (100): {avg_score:.2f} | Epsilon: {epsilon:.2f} | Steps: {steps}")

env.close()
print("Double DQN Training Finished.")
# Out:
# Atari Engine Loaded: 0.11.2
# STARTING DOUBLE DQN (DDQN) EXPERIMENT (5000 Episodes)...
# DDQN Ep: 0 | Score: 0.0 | Avg (100): 0.00 | Epsilon: 1.00 | Steps: 136
# DDQN Ep: 10 | Score: 2.0 | Avg (100): 0.64 | Epsilon: 0.99 | Steps: 1818
# DDQN Ep: 20 | Score: 0.0 | Avg (100): 0.86 | Epsilon: 0.98 | Steps: 3598
# DDQN Ep: 30 | Score: 0.0 | Avg (100): 0.71 | Epsilon: 0.97 | Steps: 5098
# DDQN Ep: 40 | Score: 2.0 | Avg (100): 0.95 | Epsilon: 0.95 | Steps: 7174
# DDQN Ep: 50 | Score: 2.0 | Avg (100): 1.04 | Epsilon: 0.94 | Steps: 9043
# DDQN Ep: 60 | Score: 1.0 | Avg (100): 1.02 | Epsilon: 0.93 | Steps: 10764
# DDQN Ep: 70 | Score: 0.0 | Avg (100): 1.06 | Epsilon: 0.92 | Steps: 12669
# DDQN Ep: 80 | Score: 1.0 | Avg (100): 0.99 | Epsilon: 0.91 | Steps: 14263
# DDQN Ep: 90 | Score: 2.0 | Avg (100): 0.98 | Epsilon: 0.90 | Steps: 15941
# DDQN Ep: 100 | Score: 0.0 | Avg (100): 1.01 | Epsilon: 0.89 | Steps: 17796
# DDQN Ep: 110 | Score: 1.0 | Avg (100): 1.05 | Epsilon: 0.88 | Steps: 19598
# DDQN Ep: 120 | Score: 0.0 | Avg (100): 0.98 | Epsilon: 0.87 | Steps: 21107
# DDQN Ep: 130 | Score: 0.0 | Avg (100): 1.02 | Epsilon: 0.86 | Steps: 22819
# DDQN Ep: 140 | Score: 0.0 | Avg (100): 0.91 | Epsilon: 0.85 | Steps: 24480
# DDQN Ep: 150 | Score: 0.0 | Avg (100): 0.82 | Epsilon: 0.84 | Steps: 26001
# DDQN Ep: 160 | Score: 0.0 | Avg (100): 0.77 | Epsilon: 0.84 | Steps: 27541
# DDQN Ep: 170 | Score: 1.0 | Avg (100): 0.81 | Epsilon: 0.82 | Steps: 29611
# DDQN Ep: 180 | Score: 2.0 | Avg (100): 0.88 | Epsilon: 0.81 | Steps: 31415
# DDQN Ep: 190 | Score: 1.0 | Avg (100): 0.97 | Epsilon: 0.80 | Steps: 33309
# DDQN Ep: 200 | Score: 2.0 | Avg (100): 1.04 | Epsilon: 0.79 | Steps: 35310
# DDQN Ep: 210 | Score: 2.0 | Avg (100): 1.10 | Epsilon: 0.78 | Steps: 37290
# DDQN Ep: 220 | Score: 1.0 | Avg (100): 1.24 | Epsilon: 0.77 | Steps: 39297
# DDQN Ep: 230 | Score: 2.0 | Avg (100): 1.33 | Epsilon: 0.76 | Steps: 41226
# DDQN Ep: 240 | Score: 2.0 | Avg (100): 1.46 | Epsilon: 0.75 | Steps: 43227
# DDQN Ep: 250 | Score: 2.0 | Avg (100): 1.72 | Epsilon: 0.74 | Steps: 45785
# DDQN Ep: 260 | Score: 2.0 | Avg (100): 1.92 | Epsilon: 0.73 | Steps: 47928
# DDQN Ep: 270 | Score: 0.0 | Avg (100): 2.01 | Epsilon: 0.72 | Steps: 50076
# DDQN Ep: 280 | Score: 2.0 | Avg (100): 2.12 | Epsilon: 0.71 | Steps: 52297
# DDQN Ep: 290 | Score: 0.0 | Avg (100): 2.19 | Epsilon: 0.70 | Steps: 54557
# DDQN Ep: 300 | Score: 4.0 | Avg (100): 2.26 | Epsilon: 0.69 | Steps: 56883
# DDQN Ep: 310 | Score: 3.0 | Avg (100): 2.41 | Epsilon: 0.68 | Steps: 59431
# DDQN Ep: 320 | Score: 3.0 | Avg (100): 2.50 | Epsilon: 0.67 | Steps: 61686
# DDQN Ep: 330 | Score: 4.0 | Avg (100): 2.63 | Epsilon: 0.66 | Steps: 64176
# DDQN Ep: 340 | Score: 3.0 | Avg (100): 2.81 | Epsilon: 0.65 | Steps: 66843
# DDQN Ep: 350 | Score: 5.0 | Avg (100): 2.80 | Epsilon: 0.64 | Steps: 69370
# DDQN Ep: 360 | Score: 6.0 | Avg (100): 2.90 | Epsilon: 0.63 | Steps: 72054
# DDQN Ep: 370 | Score: 3.0 | Avg (100): 3.01 | Epsilon: 0.62 | Steps: 74760
# DDQN Ep: 380 | Score: 3.0 | Avg (100): 3.09 | Epsilon: 0.61 | Steps: 77163
# DDQN Ep: 390 | Score: 3.0 | Avg (100): 3.18 | Epsilon: 0.60 | Steps: 79489
# DDQN Ep: 400 | Score: 1.0 | Avg (100): 3.25 | Epsilon: 0.59 | Steps: 81923
# DDQN Ep: 410 | Score: 3.0 | Avg (100): 3.24 | Epsilon: 0.58 | Steps: 84611
# DDQN Ep: 420 | Score: 8.0 | Avg (100): 3.38 | Epsilon: 0.57 | Steps: 87570
# DDQN Ep: 430 | Score: 8.0 | Avg (100): 3.54 | Epsilon: 0.56 | Steps: 90680
# DDQN Ep: 440 | Score: 3.0 | Avg (100): 3.70 | Epsilon: 0.54 | Steps: 93828
# DDQN Ep: 450 | Score: 7.0 | Avg (100): 3.90 | Epsilon: 0.53 | Steps: 96920
# DDQN Ep: 460 | Score: 5.0 | Avg (100): 3.95 | Epsilon: 0.52 | Steps: 99614
# DDQN Ep: 470 | Score: 3.0 | Avg (100): 4.08 | Epsilon: 0.51 | Steps: 102746
# DDQN Ep: 480 | Score: 7.0 | Avg (100): 4.33 | Epsilon: 0.50 | Steps: 106327
# DDQN Ep: 490 | Score: 5.0 | Avg (100): 4.62 | Epsilon: 0.49 | Steps: 109830
# DDQN Ep: 500 | Score: 9.0 | Avg (100): 4.89 | Epsilon: 0.48 | Steps: 113415
# DDQN Ep: 510 | Score: 9.0 | Avg (100): 5.18 | Epsilon: 0.47 | Steps: 116864
# DDQN Ep: 520 | Score: 1.0 | Avg (100): 5.20 | Epsilon: 0.46 | Steps: 119855
# DDQN Ep: 530 | Score: 8.0 | Avg (100): 5.19 | Epsilon: 0.45 | Steps: 123003
# DDQN Ep: 540 | Score: 6.0 | Avg (100): 5.18 | Epsilon: 0.44 | Steps: 126148
# DDQN Ep: 550 | Score: 4.0 | Avg (100): 5.36 | Epsilon: 0.43 | Steps: 129802
# DDQN Ep: 560 | Score: 3.0 | Avg (100): 5.54 | Epsilon: 0.42 | Steps: 133285
# DDQN Ep: 570 | Score: 10.0 | Avg (100): 5.76 | Epsilon: 0.41 | Steps: 137079
# DDQN Ep: 580 | Score: 7.0 | Avg (100): 6.03 | Epsilon: 0.40 | Steps: 141250
# DDQN Ep: 590 | Score: 7.0 | Avg (100): 6.09 | Epsilon: 0.39 | Steps: 145139
# DDQN Ep: 600 | Score: 6.0 | Avg (100): 6.18 | Epsilon: 0.38 | Steps: 149058
# DDQN Ep: 610 | Score: 7.0 | Avg (100): 6.24 | Epsilon: 0.37 | Steps: 152454
# DDQN Ep: 620 | Score: 5.0 | Avg (100): 6.63 | Epsilon: 0.37 | Steps: 156300
# DDQN Ep: 630 | Score: 6.0 | Avg (100): 6.87 | Epsilon: 0.36 | Steps: 159787
# DDQN Ep: 640 | Score: 11.0 | Avg (100): 7.33 | Epsilon: 0.35 | Steps: 164159
# DDQN Ep: 650 | Score: 6.0 | Avg (100): 7.50 | Epsilon: 0.34 | Steps: 168241
# DDQN Ep: 660 | Score: 14.0 | Avg (100): 7.82 | Epsilon: 0.33 | Steps: 172538
# DDQN Ep: 670 | Score: 8.0 | Avg (100): 7.98 | Epsilon: 0.32 | Steps: 176740
# DDQN Ep: 680 | Score: 10.0 | Avg (100): 7.93 | Epsilon: 0.31 | Steps: 180858
# DDQN Ep: 690 | Score: 8.0 | Avg (100): 8.05 | Epsilon: 0.31 | Steps: 184677
# DDQN Ep: 700 | Score: 10.0 | Avg (100): 8.19 | Epsilon: 0.30 | Steps: 188736
# DDQN Ep: 710 | Score: 6.0 | Avg (100): 8.37 | Epsilon: 0.29 | Steps: 192817
# DDQN Ep: 720 | Score: 10.0 | Avg (100): 8.52 | Epsilon: 0.28 | Steps: 196898
# DDQN Ep: 730 | Score: 7.0 | Avg (100): 8.95 | Epsilon: 0.28 | Steps: 201447
# DDQN Ep: 740 | Score: 11.0 | Avg (100): 8.99 | Epsilon: 0.27 | Steps: 205895
# DDQN Ep: 750 | Score: 3.0 | Avg (100): 8.89 | Epsilon: 0.26 | Steps: 209657
# DDQN Ep: 760 | Score: 18.0 | Avg (100): 9.06 | Epsilon: 0.25 | Steps: 214263
# DDQN Ep: 770 | Score: 15.0 | Avg (100): 9.19 | Epsilon: 0.25 | Steps: 218598
# DDQN Ep: 780 | Score: 10.0 | Avg (100): 9.36 | Epsilon: 0.24 | Steps: 223148
# DDQN Ep: 790 | Score: 9.0 | Avg (100): 9.78 | Epsilon: 0.23 | Steps: 228033
# DDQN Ep: 800 | Score: 9.0 | Avg (100): 10.06 | Epsilon: 0.23 | Steps: 232869
# DDQN Ep: 810 | Score: 11.0 | Avg (100): 10.29 | Epsilon: 0.22 | Steps: 237116
# DDQN Ep: 820 | Score: 5.0 | Avg (100): 10.44 | Epsilon: 0.22 | Steps: 241637
# DDQN Ep: 830 | Score: 9.0 | Avg (100): 10.05 | Epsilon: 0.21 | Steps: 245484
# DDQN Ep: 840 | Score: 6.0 | Avg (100): 9.87 | Epsilon: 0.21 | Steps: 249553
# DDQN Ep: 850 | Score: 12.0 | Avg (100): 10.14 | Epsilon: 0.20 | Steps: 253637
# DDQN Ep: 860 | Score: 11.0 | Avg (100): 10.35 | Epsilon: 0.20 | Steps: 258245
# DDQN Ep: 870 | Score: 16.0 | Avg (100): 10.44 | Epsilon: 0.19 | Steps: 262794
# DDQN Ep: 880 | Score: 5.0 | Avg (100): 10.57 | Epsilon: 0.18 | Steps: 267255
# DDQN Ep: 890 | Score: 11.0 | Avg (100): 10.60 | Epsilon: 0.18 | Steps: 271800
# DDQN Ep: 900 | Score: 15.0 | Avg (100): 10.91 | Epsilon: 0.18 | Steps: 276462
# DDQN Ep: 910 | Score: 8.0 | Avg (100): 11.16 | Epsilon: 0.17 | Steps: 281038
# DDQN Ep: 920 | Score: 9.0 | Avg (100): 11.18 | Epsilon: 0.17 | Steps: 285514
# DDQN Ep: 930 | Score: 13.0 | Avg (100): 11.53 | Epsilon: 0.16 | Steps: 289903
# DDQN Ep: 940 | Score: 10.0 | Avg (100): 12.03 | Epsilon: 0.16 | Steps: 294236
# DDQN Ep: 950 | Score: 13.0 | Avg (100): 12.56 | Epsilon: 0.15 | Steps: 298787
# DDQN Ep: 960 | Score: 5.0 | Avg (100): 12.43 | Epsilon: 0.15 | Steps: 302580
# DDQN Ep: 970 | Score: 7.0 | Avg (100): 11.80 | Epsilon: 0.15 | Steps: 305684
# DDQN Ep: 980 | Score: 3.0 | Avg (100): 11.84 | Epsilon: 0.14 | Steps: 309864
# DDQN Ep: 990 | Score: 7.0 | Avg (100): 11.75 | Epsilon: 0.14 | Steps: 314022
# DDQN Ep: 1000 | Score: 9.0 | Avg (100): 11.48 | Epsilon: 0.14 | Steps: 318784
# DDQN Ep: 1010 | Score: 17.0 | Avg (100): 11.57 | Epsilon: 0.13 | Steps: 323673
# DDQN Ep: 1020 | Score: 11.0 | Avg (100): 11.76 | Epsilon: 0.13 | Steps: 328107
# DDQN Ep: 1030 | Score: 22.0 | Avg (100): 11.79 | Epsilon: 0.13 | Steps: 332089
# DDQN Ep: 1040 | Score: 9.0 | Avg (100): 11.62 | Epsilon: 0.12 | Steps: 336369
# DDQN Ep: 1050 | Score: 9.0 | Avg (100): 11.06 | Epsilon: 0.12 | Steps: 339994
# DDQN Ep: 1060 | Score: 13.0 | Avg (100): 10.91 | Epsilon: 0.12 | Steps: 343980
# DDQN Ep: 1070 | Score: 10.0 | Avg (100): 11.61 | Epsilon: 0.12 | Steps: 348351
# DDQN Ep: 1080 | Score: 10.0 | Avg (100): 11.62 | Epsilon: 0.11 | Steps: 352863
# DDQN Ep: 1090 | Score: 14.0 | Avg (100): 11.41 | Epsilon: 0.11 | Steps: 356976
# DDQN Ep: 1100 | Score: 14.0 | Avg (100): 11.51 | Epsilon: 0.11 | Steps: 361596
# DDQN Ep: 1110 | Score: 19.0 | Avg (100): 11.41 | Epsilon: 0.11 | Steps: 366349
# DDQN Ep: 1120 | Score: 11.0 | Avg (100): 11.05 | Epsilon: 0.10 | Steps: 369974
# DDQN Ep: 1130 | Score: 17.0 | Avg (100): 10.82 | Epsilon: 0.10 | Steps: 373586
# DDQN Ep: 1140 | Score: 17.0 | Avg (100): 11.46 | Epsilon: 0.10 | Steps: 379137
# DDQN Ep: 1150 | Score: 13.0 | Avg (100): 12.06 | Epsilon: 0.10 | Steps: 383624
# DDQN Ep: 1160 | Score: 16.0 | Avg (100): 12.15 | Epsilon: 0.09 | Steps: 387791
# DDQN Ep: 1170 | Score: 21.0 | Avg (100): 12.33 | Epsilon: 0.09 | Steps: 392323
# DDQN Ep: 1180 | Score: 18.0 | Avg (100): 12.55 | Epsilon: 0.09 | Steps: 396871
# DDQN Ep: 1190 | Score: 19.0 | Avg (100): 13.18 | Epsilon: 0.09 | Steps: 401215
# DDQN Ep: 1200 | Score: 19.0 | Avg (100): 13.16 | Epsilon: 0.09 | Steps: 405323
# DDQN Ep: 1210 | Score: 19.0 | Avg (100): 13.57 | Epsilon: 0.08 | Steps: 410231
# DDQN Ep: 1220 | Score: 29.0 | Avg (100): 14.28 | Epsilon: 0.08 | Steps: 414647
# DDQN Ep: 1230 | Score: 18.0 | Avg (100): 14.79 | Epsilon: 0.08 | Steps: 418945
# DDQN Ep: 1240 | Score: 18.0 | Avg (100): 14.42 | Epsilon: 0.08 | Steps: 423084
# DDQN Ep: 1250 | Score: 5.0 | Avg (100): 14.21 | Epsilon: 0.08 | Steps: 427332
# DDQN Ep: 1260 | Score: 4.0 | Avg (100): 14.56 | Epsilon: 0.08 | Steps: 431382
# DDQN Ep: 1270 | Score: 14.0 | Avg (100): 14.76 | Epsilon: 0.07 | Steps: 435701
# DDQN Ep: 1280 | Score: 23.0 | Avg (100): 14.82 | Epsilon: 0.07 | Steps: 440358
# DDQN Ep: 1290 | Score: 12.0 | Avg (100): 14.91 | Epsilon: 0.07 | Steps: 445200
# DDQN Ep: 1300 | Score: 26.0 | Avg (100): 15.38 | Epsilon: 0.07 | Steps: 449833
# DDQN Ep: 1310 | Score: 8.0 | Avg (100): 15.12 | Epsilon: 0.07 | Steps: 454189
# DDQN Ep: 1320 | Score: 22.0 | Avg (100): 14.91 | Epsilon: 0.07 | Steps: 458213
# DDQN Ep: 1330 | Score: 18.0 | Avg (100): 14.96 | Epsilon: 0.06 | Steps: 462389
# DDQN Ep: 1340 | Score: 27.0 | Avg (100): 14.97 | Epsilon: 0.06 | Steps: 467013
# DDQN Ep: 1350 | Score: 19.0 | Avg (100): 15.39 | Epsilon: 0.06 | Steps: 471118
# DDQN Ep: 1360 | Score: 21.0 | Avg (100): 15.64 | Epsilon: 0.06 | Steps: 475492
# DDQN Ep: 1370 | Score: 11.0 | Avg (100): 15.71 | Epsilon: 0.06 | Steps: 479993
# DDQN Ep: 1380 | Score: 14.0 | Avg (100): 15.49 | Epsilon: 0.06 | Steps: 484050
# DDQN Ep: 1390 | Score: 6.0 | Avg (100): 15.41 | Epsilon: 0.06 | Steps: 488169
# DDQN Ep: 1400 | Score: 14.0 | Avg (100): 15.56 | Epsilon: 0.06 | Steps: 493054
# DDQN Ep: 1410 | Score: 15.0 | Avg (100): 15.53 | Epsilon: 0.06 | Steps: 497485
# DDQN Ep: 1420 | Score: 18.0 | Avg (100): 15.47 | Epsilon: 0.05 | Steps: 500960
# DDQN Ep: 1430 | Score: 17.0 | Avg (100): 16.00 | Epsilon: 0.05 | Steps: 505503
# DDQN Ep: 1440 | Score: 19.0 | Avg (100): 16.50 | Epsilon: 0.05 | Steps: 509819
# DDQN Ep: 1450 | Score: 5.0 | Avg (100): 16.21 | Epsilon: 0.05 | Steps: 514140
# DDQN Ep: 1460 | Score: 22.0 | Avg (100): 16.09 | Epsilon: 0.05 | Steps: 518541
# DDQN Ep: 1470 | Score: 17.0 | Avg (100): 16.32 | Epsilon: 0.05 | Steps: 523267
# DDQN Ep: 1480 | Score: 19.0 | Avg (100): 17.05 | Epsilon: 0.05 | Steps: 527436
# DDQN Ep: 1490 | Score: 24.0 | Avg (100): 17.15 | Epsilon: 0.05 | Steps: 531554
# DDQN Ep: 1500 | Score: 31.0 | Avg (100): 17.38 | Epsilon: 0.05 | Steps: 535623
# DDQN Ep: 1510 | Score: 6.0 | Avg (100): 17.76 | Epsilon: 0.05 | Steps: 540510
# DDQN Ep: 1520 | Score: 15.0 | Avg (100): 18.29 | Epsilon: 0.05 | Steps: 545561
# DDQN Ep: 1530 | Score: 21.0 | Avg (100): 18.62 | Epsilon: 0.05 | Steps: 549706
# DDQN Ep: 1540 | Score: 23.0 | Avg (100): 19.11 | Epsilon: 0.04 | Steps: 554016
# DDQN Ep: 1550 | Score: 14.0 | Avg (100): 19.77 | Epsilon: 0.04 | Steps: 557790
# DDQN Ep: 1560 | Score: 20.0 | Avg (100): 20.26 | Epsilon: 0.04 | Steps: 561631
# DDQN Ep: 1570 | Score: 30.0 | Avg (100): 20.72 | Epsilon: 0.04 | Steps: 565866
# DDQN Ep: 1580 | Score: 13.0 | Avg (100): 21.35 | Epsilon: 0.04 | Steps: 569995
# DDQN Ep: 1590 | Score: 29.0 | Avg (100): 22.10 | Epsilon: 0.04 | Steps: 574015
# DDQN Ep: 1600 | Score: 28.0 | Avg (100): 22.05 | Epsilon: 0.04 | Steps: 577796
# DDQN Ep: 1610 | Score: 28.0 | Avg (100): 22.60 | Epsilon: 0.04 | Steps: 582147
# DDQN Ep: 1620 | Score: 29.0 | Avg (100): 23.36 | Epsilon: 0.04 | Steps: 586286
# DDQN Ep: 1630 | Score: 15.0 | Avg (100): 23.72 | Epsilon: 0.04 | Steps: 590332
# DDQN Ep: 1640 | Score: 29.0 | Avg (100): 24.09 | Epsilon: 0.04 | Steps: 594275
# DDQN Ep: 1650 | Score: 29.0 | Avg (100): 24.73 | Epsilon: 0.04 | Steps: 598311
# DDQN Ep: 1660 | Score: 28.0 | Avg (100): 25.59 | Epsilon: 0.04 | Steps: 602632
# DDQN Ep: 1670 | Score: 30.0 | Avg (100): 25.76 | Epsilon: 0.04 | Steps: 606544
# DDQN Ep: 1680 | Score: 30.0 | Avg (100): 25.89 | Epsilon: 0.04 | Steps: 610654
# DDQN Ep: 1690 | Score: 30.0 | Avg (100): 26.39 | Epsilon: 0.04 | Steps: 614837
# DDQN Ep: 1700 | Score: 28.0 | Avg (100): 27.00 | Epsilon: 0.04 | Steps: 618929
# DDQN Ep: 1710 | Score: 30.0 | Avg (100): 27.26 | Epsilon: 0.04 | Steps: 622996
# DDQN Ep: 1720 | Score: 30.0 | Avg (100): 27.27 | Epsilon: 0.03 | Steps: 627083
# DDQN Ep: 1730 | Score: 21.0 | Avg (100): 27.37 | Epsilon: 0.03 | Steps: 631411
# DDQN Ep: 1740 | Score: 30.0 | Avg (100): 27.36 | Epsilon: 0.03 | Steps: 635390
# DDQN Ep: 1750 | Score: 30.0 | Avg (100): 27.22 | Epsilon: 0.03 | Steps: 639380
# DDQN Ep: 1760 | Score: 30.0 | Avg (100): 27.08 | Epsilon: 0.03 | Steps: 643542
# DDQN Ep: 1770 | Score: 30.0 | Avg (100): 27.49 | Epsilon: 0.03 | Steps: 647642
# DDQN Ep: 1780 | Score: 30.0 | Avg (100): 27.86 | Epsilon: 0.03 | Steps: 652029
# DDQN Ep: 1790 | Score: 30.0 | Avg (100): 27.58 | Epsilon: 0.03 | Steps: 656128
# DDQN Ep: 1800 | Score: 33.0 | Avg (100): 27.78 | Epsilon: 0.03 | Steps: 660325
# DDQN Ep: 1810 | Score: 25.0 | Avg (100): 28.00 | Epsilon: 0.03 | Steps: 665417
# DDQN Ep: 1820 | Score: 28.0 | Avg (100): 27.96 | Epsilon: 0.03 | Steps: 669685
# DDQN Ep: 1830 | Score: 29.0 | Avg (100): 27.91 | Epsilon: 0.03 | Steps: 673855
# DDQN Ep: 1840 | Score: 18.0 | Avg (100): 28.08 | Epsilon: 0.03 | Steps: 678184
# DDQN Ep: 1850 | Score: 30.0 | Avg (100): 28.34 | Epsilon: 0.03 | Steps: 682461
# DDQN Ep: 1860 | Score: 34.0 | Avg (100): 28.66 | Epsilon: 0.03 | Steps: 687087
# DDQN Ep: 1870 | Score: 40.0 | Avg (100): 28.69 | Epsilon: 0.03 | Steps: 691474
# DDQN Ep: 1880 | Score: 23.0 | Avg (100): 28.49 | Epsilon: 0.03 | Steps: 695978
# DDQN Ep: 1890 | Score: 36.0 | Avg (100): 28.55 | Epsilon: 0.03 | Steps: 700344
# DDQN Ep: 1900 | Score: 36.0 | Avg (100): 28.59 | Epsilon: 0.03 | Steps: 704870
# DDQN Ep: 1910 | Score: 21.0 | Avg (100): 29.20 | Epsilon: 0.03 | Steps: 709578
# DDQN Ep: 1920 | Score: 16.0 | Avg (100): 29.53 | Epsilon: 0.03 | Steps: 714199
# DDQN Ep: 1930 | Score: 36.0 | Avg (100): 30.34 | Epsilon: 0.03 | Steps: 718910
# DDQN Ep: 1940 | Score: 32.0 | Avg (100): 30.74 | Epsilon: 0.03 | Steps: 723553
# DDQN Ep: 1950 | Score: 40.0 | Avg (100): 31.46 | Epsilon: 0.03 | Steps: 728298
# DDQN Ep: 1960 | Score: 25.0 | Avg (100): 31.75 | Epsilon: 0.03 | Steps: 733031
# DDQN Ep: 1970 | Score: 48.0 | Avg (100): 32.41 | Epsilon: 0.03 | Steps: 737989
# DDQN Ep: 1980 | Score: 30.0 | Avg (100): 32.62 | Epsilon: 0.03 | Steps: 742374
# DDQN Ep: 1990 | Score: 35.0 | Avg (100): 33.19 | Epsilon: 0.03 | Steps: 747086
# DDQN Ep: 2000 | Score: 29.0 | Avg (100): 33.41 | Epsilon: 0.03 | Steps: 751637
# DDQN Ep: 2010 | Score: 42.0 | Avg (100): 33.92 | Epsilon: 0.03 | Steps: 756647
# DDQN Ep: 2020 | Score: 41.0 | Avg (100): 34.04 | Epsilon: 0.03 | Steps: 761055
# DDQN Ep: 2030 | Score: 47.0 | Avg (100): 34.43 | Epsilon: 0.03 | Steps: 766113
# DDQN Ep: 2040 | Score: 36.0 | Avg (100): 34.13 | Epsilon: 0.03 | Steps: 771758
# DDQN Ep: 2050 | Score: 9.0 | Avg (100): 34.07 | Epsilon: 0.03 | Steps: 776572
# DDQN Ep: 2060 | Score: 43.0 | Avg (100): 33.83 | Epsilon: 0.03 | Steps: 781113
# DDQN Ep: 2070 | Score: 30.0 | Avg (100): 33.43 | Epsilon: 0.03 | Steps: 785807
# DDQN Ep: 2080 | Score: 28.0 | Avg (100): 33.97 | Epsilon: 0.03 | Steps: 790620
# DDQN Ep: 2090 | Score: 54.0 | Avg (100): 33.95 | Epsilon: 0.02 | Steps: 795368
# DDQN Ep: 2100 | Score: 49.0 | Avg (100): 35.05 | Epsilon: 0.02 | Steps: 800499
# DDQN Ep: 2110 | Score: 31.0 | Avg (100): 34.27 | Epsilon: 0.02 | Steps: 805733
# DDQN Ep: 2120 | Score: 48.0 | Avg (100): 34.75 | Epsilon: 0.02 | Steps: 811333
# DDQN Ep: 2130 | Score: 53.0 | Avg (100): 34.60 | Epsilon: 0.02 | Steps: 816610
# DDQN Ep: 2140 | Score: 32.0 | Avg (100): 35.42 | Epsilon: 0.02 | Steps: 821487
# DDQN Ep: 2150 | Score: 23.0 | Avg (100): 34.93 | Epsilon: 0.02 | Steps: 826711
# DDQN Ep: 2160 | Score: 37.0 | Avg (100): 37.31 | Epsilon: 0.02 | Steps: 831994
# DDQN Ep: 2170 | Score: 6.0 | Avg (100): 40.26 | Epsilon: 0.02 | Steps: 837469
# DDQN Ep: 2180 | Score: 54.0 | Avg (100): 40.97 | Epsilon: 0.02 | Steps: 842763
# DDQN Ep: 2190 | Score: 35.0 | Avg (100): 44.88 | Epsilon: 0.02 | Steps: 848331
# DDQN Ep: 2200 | Score: 59.0 | Avg (100): 47.18 | Epsilon: 0.02 | Steps: 853838
# DDQN Ep: 2210 | Score: 72.0 | Avg (100): 50.34 | Epsilon: 0.02 | Steps: 859069
# DDQN Ep: 2220 | Score: 62.0 | Avg (100): 52.57 | Epsilon: 0.02 | Steps: 864525
# DDQN Ep: 2230 | Score: 59.0 | Avg (100): 53.47 | Epsilon: 0.02 | Steps: 869968
# DDQN Ep: 2240 | Score: 29.0 | Avg (100): 53.37 | Epsilon: 0.02 | Steps: 874798
# DDQN Ep: 2250 | Score: 69.0 | Avg (100): 57.93 | Epsilon: 0.02 | Steps: 880680
# DDQN Ep: 2260 | Score: 62.0 | Avg (100): 57.24 | Epsilon: 0.02 | Steps: 885816
# DDQN Ep: 2270 | Score: 24.0 | Avg (100): 59.80 | Epsilon: 0.02 | Steps: 891534
# DDQN Ep: 2280 | Score: 65.0 | Avg (100): 62.56 | Epsilon: 0.02 | Steps: 898205
# DDQN Ep: 2290 | Score: 40.0 | Avg (100): 64.17 | Epsilon: 0.02 | Steps: 904811
# DDQN Ep: 2300 | Score: 51.0 | Avg (100): 63.58 | Epsilon: 0.02 | Steps: 910426
# DDQN Ep: 2310 | Score: 46.0 | Avg (100): 63.30 | Epsilon: 0.02 | Steps: 916470
# DDQN Ep: 2320 | Score: 82.0 | Avg (100): 64.44 | Epsilon: 0.02 | Steps: 922104
# DDQN Ep: 2330 | Score: 46.0 | Avg (100): 64.22 | Epsilon: 0.02 | Steps: 927618
# DDQN Ep: 2340 | Score: 33.0 | Avg (100): 65.31 | Epsilon: 0.02 | Steps: 933293
# DDQN Ep: 2350 | Score: 48.0 | Avg (100): 61.52 | Epsilon: 0.02 | Steps: 938190
# DDQN Ep: 2360 | Score: 25.0 | Avg (100): 61.06 | Epsilon: 0.02 | Steps: 943013
# DDQN Ep: 2370 | Score: 25.0 | Avg (100): 57.81 | Epsilon: 0.02 | Steps: 948447
# DDQN Ep: 2380 | Score: 46.0 | Avg (100): 56.15 | Epsilon: 0.02 | Steps: 953975
# DDQN Ep: 2390 | Score: 39.0 | Avg (100): 51.30 | Epsilon: 0.02 | Steps: 959036
# DDQN Ep: 2400 | Score: 80.0 | Avg (100): 50.42 | Epsilon: 0.02 | Steps: 965064
# DDQN Ep: 2410 | Score: 5.0 | Avg (100): 47.75 | Epsilon: 0.02 | Steps: 969587
# DDQN Ep: 2420 | Score: 30.0 | Avg (100): 44.91 | Epsilon: 0.02 | Steps: 974566
# DDQN Ep: 2430 | Score: 29.0 | Avg (100): 44.59 | Epsilon: 0.02 | Steps: 979496
# DDQN Ep: 2440 | Score: 87.0 | Avg (100): 51.98 | Epsilon: 0.02 | Steps: 986074
# DDQN Ep: 2450 | Score: 44.0 | Avg (100): 52.73 | Epsilon: 0.02 | Steps: 990605
# DDQN Ep: 2460 | Score: 34.0 | Avg (100): 54.26 | Epsilon: 0.02 | Steps: 995971
# DDQN Ep: 2470 | Score: 163.0 | Avg (100): 56.54 | Epsilon: 0.02 | Steps: 1001713
# DDQN Ep: 2480 | Score: 243.0 | Avg (100): 57.59 | Epsilon: 0.02 | Steps: 1008517
# DDQN Ep: 2490 | Score: 244.0 | Avg (100): 64.98 | Epsilon: 0.02 | Steps: 1014547
# DDQN Ep: 2500 | Score: 3.0 | Avg (100): 71.03 | Epsilon: 0.02 | Steps: 1020365
# DDQN Ep: 2510 | Score: 34.0 | Avg (100): 73.48 | Epsilon: 0.02 | Steps: 1025601
# DDQN Ep: 2520 | Score: 4.0 | Avg (100): 73.15 | Epsilon: 0.02 | Steps: 1030079
# DDQN Ep: 2530 | Score: 54.0 | Avg (100): 75.83 | Epsilon: 0.02 | Steps: 1035522
# DDQN Ep: 2540 | Score: 244.0 | Avg (100): 71.47 | Epsilon: 0.02 | Steps: 1040932
# DDQN Ep: 2550 | Score: 37.0 | Avg (100): 77.19 | Epsilon: 0.02 | Steps: 1046767
# DDQN Ep: 2560 | Score: 3.0 | Avg (100): 74.86 | Epsilon: 0.02 | Steps: 1050984
# DDQN Ep: 2570 | Score: 76.0 | Avg (100): 75.10 | Epsilon: 0.02 | Steps: 1056358
# DDQN Ep: 2580 | Score: 7.0 | Avg (100): 76.41 | Epsilon: 0.02 | Steps: 1061694
# DDQN Ep: 2590 | Score: 24.0 | Avg (100): 75.97 | Epsilon: 0.02 | Steps: 1067708
# DDQN Ep: 2600 | Score: 243.0 | Avg (100): 75.12 | Epsilon: 0.02 | Steps: 1073515
# DDQN Ep: 2610 | Score: 244.0 | Avg (100): 81.57 | Epsilon: 0.02 | Steps: 1080165
# DDQN Ep: 2620 | Score: 6.0 | Avg (100): 89.16 | Epsilon: 0.02 | Steps: 1086039
# DDQN Ep: 2630 | Score: 244.0 | Avg (100): 88.82 | Epsilon: 0.02 | Steps: 1092137
# DDQN Ep: 2640 | Score: 47.0 | Avg (100): 94.42 | Epsilon: 0.02 | Steps: 1098654
# DDQN Ep: 2650 | Score: 20.0 | Avg (100): 92.11 | Epsilon: 0.02 | Steps: 1105384
# DDQN Ep: 2660 | Score: 33.0 | Avg (100): 95.82 | Epsilon: 0.02 | Steps: 1110448
# DDQN Ep: 2670 | Score: 58.0 | Avg (100): 97.76 | Epsilon: 0.02 | Steps: 1116317
# DDQN Ep: 2680 | Score: 9.0 | Avg (100): 98.84 | Epsilon: 0.02 | Steps: 1121669
# DDQN Ep: 2690 | Score: 18.0 | Avg (100): 96.16 | Epsilon: 0.02 | Steps: 1128049
# DDQN Ep: 2700 | Score: 167.0 | Avg (100): 90.36 | Epsilon: 0.02 | Steps: 1132993
# DDQN Ep: 2710 | Score: 51.0 | Avg (100): 89.52 | Epsilon: 0.02 | Steps: 1139097
# DDQN Ep: 2720 | Score: 167.0 | Avg (100): 86.43 | Epsilon: 0.02 | Steps: 1144942
# DDQN Ep: 2730 | Score: 45.0 | Avg (100): 91.69 | Epsilon: 0.02 | Steps: 1151285
# DDQN Ep: 2740 | Score: 17.0 | Avg (100): 95.34 | Epsilon: 0.02 | Steps: 1159317
# DDQN Ep: 2750 | Score: 23.0 | Avg (100): 98.02 | Epsilon: 0.02 | Steps: 1165085
# DDQN Ep: 2760 | Score: 41.0 | Avg (100): 102.41 | Epsilon: 0.02 | Steps: 1171307
# DDQN Ep: 2770 | Score: 32.0 | Avg (100): 101.39 | Epsilon: 0.02 | Steps: 1177048
# DDQN Ep: 2780 | Score: 294.0 | Avg (100): 108.96 | Epsilon: 0.02 | Steps: 1184201
# DDQN Ep: 2790 | Score: 45.0 | Avg (100): 111.51 | Epsilon: 0.02 | Steps: 1190535
# DDQN Ep: 2800 | Score: 167.0 | Avg (100): 115.68 | Epsilon: 0.02 | Steps: 1196003
# DDQN Ep: 2810 | Score: 36.0 | Avg (100): 113.25 | Epsilon: 0.02 | Steps: 1201551
# DDQN Ep: 2820 | Score: 46.0 | Avg (100): 112.88 | Epsilon: 0.02 | Steps: 1206959
# DDQN Ep: 2830 | Score: 31.0 | Avg (100): 112.10 | Epsilon: 0.02 | Steps: 1213012
# DDQN Ep: 2840 | Score: 13.0 | Avg (100): 102.87 | Epsilon: 0.02 | Steps: 1218427
# DDQN Ep: 2850 | Score: 178.0 | Avg (100): 107.93 | Epsilon: 0.02 | Steps: 1224943
# DDQN Ep: 2860 | Score: 47.0 | Avg (100): 106.32 | Epsilon: 0.02 | Steps: 1230865
# DDQN Ep: 2870 | Score: 174.0 | Avg (100): 105.77 | Epsilon: 0.02 | Steps: 1236193
# DDQN Ep: 2880 | Score: 6.0 | Avg (100): 99.97 | Epsilon: 0.02 | Steps: 1242046
# DDQN Ep: 2890 | Score: 2.0 | Avg (100): 98.35 | Epsilon: 0.02 | Steps: 1248232
# DDQN Ep: 2900 | Score: 35.0 | Avg (100): 94.48 | Epsilon: 0.02 | Steps: 1254277
# DDQN Ep: 2910 | Score: 53.0 | Avg (100): 90.54 | Epsilon: 0.02 | Steps: 1258591
# DDQN Ep: 2920 | Score: 4.0 | Avg (100): 90.66 | Epsilon: 0.02 | Steps: 1263802
# DDQN Ep: 2930 | Score: 31.0 | Avg (100): 85.32 | Epsilon: 0.02 | Steps: 1268567
# DDQN Ep: 2940 | Score: 51.0 | Avg (100): 79.21 | Epsilon: 0.02 | Steps: 1272042
# DDQN Ep: 2950 | Score: 274.0 | Avg (100): 76.02 | Epsilon: 0.02 | Steps: 1278155
# DDQN Ep: 2960 | Score: 69.0 | Avg (100): 75.63 | Epsilon: 0.02 | Steps: 1284392
# DDQN Ep: 2970 | Score: 58.0 | Avg (100): 75.01 | Epsilon: 0.02 | Steps: 1289800
# DDQN Ep: 2980 | Score: 193.0 | Avg (100): 74.31 | Epsilon: 0.02 | Steps: 1296206
# DDQN Ep: 2990 | Score: 29.0 | Avg (100): 72.64 | Epsilon: 0.02 | Steps: 1301964
# DDQN Ep: 3000 | Score: 58.0 | Avg (100): 80.36 | Epsilon: 0.02 | Steps: 1308463
# DDQN Ep: 3010 | Score: 9.0 | Avg (100): 87.40 | Epsilon: 0.02 | Steps: 1314515
# DDQN Ep: 3020 | Score: 53.0 | Avg (100): 92.10 | Epsilon: 0.02 | Steps: 1320991
# DDQN Ep: 3030 | Score: 34.0 | Avg (100): 96.48 | Epsilon: 0.02 | Steps: 1326668
# DDQN Ep: 3040 | Score: 32.0 | Avg (100): 104.77 | Epsilon: 0.02 | Steps: 1332191
# DDQN Ep: 3050 | Score: 28.0 | Avg (100): 96.43 | Epsilon: 0.02 | Steps: 1336638
# DDQN Ep: 3060 | Score: 274.0 | Avg (100): 101.73 | Epsilon: 0.02 | Steps: 1343431
# DDQN Ep: 3070 | Score: 274.0 | Avg (100): 105.21 | Epsilon: 0.02 | Steps: 1349076
# DDQN Ep: 3080 | Score: 48.0 | Avg (100): 105.77 | Epsilon: 0.02 | Steps: 1355101
# DDQN Ep: 3090 | Score: 35.0 | Avg (100): 109.09 | Epsilon: 0.02 | Steps: 1360747
# DDQN Ep: 3100 | Score: 55.0 | Avg (100): 107.59 | Epsilon: 0.02 | Steps: 1366667
# DDQN Ep: 3110 | Score: 274.0 | Avg (100): 116.52 | Epsilon: 0.02 | Steps: 1374731
# DDQN Ep: 3120 | Score: 18.0 | Avg (100): 114.28 | Epsilon: 0.02 | Steps: 1380489
# DDQN Ep: 3130 | Score: 98.0 | Avg (100): 116.94 | Epsilon: 0.02 | Steps: 1386575
# DDQN Ep: 3140 | Score: 220.0 | Avg (100): 123.47 | Epsilon: 0.02 | Steps: 1393641
# DDQN Ep: 3150 | Score: 274.0 | Avg (100): 132.82 | Epsilon: 0.02 | Steps: 1399935
# DDQN Ep: 3160 | Score: 274.0 | Avg (100): 128.69 | Epsilon: 0.02 | Steps: 1405487
# DDQN Ep: 3170 | Score: 23.0 | Avg (100): 125.06 | Epsilon: 0.02 | Steps: 1410859
# DDQN Ep: 3180 | Score: 31.0 | Avg (100): 123.63 | Epsilon: 0.02 | Steps: 1416092
# DDQN Ep: 3190 | Score: 51.0 | Avg (100): 119.68 | Epsilon: 0.02 | Steps: 1421289
# DDQN Ep: 3200 | Score: 46.0 | Avg (100): 118.01 | Epsilon: 0.02 | Steps: 1427299
# DDQN Ep: 3210 | Score: 274.0 | Avg (100): 105.05 | Epsilon: 0.02 | Steps: 1433353
# DDQN Ep: 3220 | Score: 45.0 | Avg (100): 101.77 | Epsilon: 0.02 | Steps: 1438933
# DDQN Ep: 3230 | Score: 193.0 | Avg (100): 98.18 | Epsilon: 0.02 | Steps: 1444352
# DDQN Ep: 3240 | Score: 270.0 | Avg (100): 96.13 | Epsilon: 0.02 | Steps: 1451655
# DDQN Ep: 3250 | Score: 31.0 | Avg (100): 87.58 | Epsilon: 0.02 | Steps: 1457002
# DDQN Ep: 3260 | Score: 270.0 | Avg (100): 86.64 | Epsilon: 0.02 | Steps: 1463070
# DDQN Ep: 3270 | Score: 35.0 | Avg (100): 86.22 | Epsilon: 0.02 | Steps: 1468434
# DDQN Ep: 3280 | Score: 32.0 | Avg (100): 81.89 | Epsilon: 0.02 | Steps: 1473116
# DDQN Ep: 3290 | Score: 31.0 | Avg (100): 81.05 | Epsilon: 0.02 | Steps: 1478225
# DDQN Ep: 3300 | Score: 54.0 | Avg (100): 80.15 | Epsilon: 0.02 | Steps: 1483858
# DDQN Ep: 3310 | Score: 47.0 | Avg (100): 81.12 | Epsilon: 0.02 | Steps: 1489577
# DDQN Ep: 3320 | Score: 62.0 | Avg (100): 83.53 | Epsilon: 0.02 | Steps: 1495093
# DDQN Ep: 3330 | Score: 55.0 | Avg (100): 86.05 | Epsilon: 0.02 | Steps: 1501050
# DDQN Ep: 3340 | Score: 221.0 | Avg (100): 83.34 | Epsilon: 0.02 | Steps: 1507357
# DDQN Ep: 3350 | Score: 34.0 | Avg (100): 88.29 | Epsilon: 0.02 | Steps: 1513405
# DDQN Ep: 3360 | Score: 195.0 | Avg (100): 90.44 | Epsilon: 0.02 | Steps: 1519267
# DDQN Ep: 3370 | Score: 274.0 | Avg (100): 95.48 | Epsilon: 0.02 | Steps: 1525437
# DDQN Ep: 3380 | Score: 29.0 | Avg (100): 99.33 | Epsilon: 0.02 | Steps: 1530894
# DDQN Ep: 3390 | Score: 42.0 | Avg (100): 108.98 | Epsilon: 0.02 | Steps: 1537680
# DDQN Ep: 3400 | Score: 4.0 | Avg (100): 108.53 | Epsilon: 0.02 | Steps: 1542621
# DDQN Ep: 3410 | Score: 274.0 | Avg (100): 106.54 | Epsilon: 0.02 | Steps: 1547114
# DDQN Ep: 3420 | Score: 30.0 | Avg (100): 105.49 | Epsilon: 0.02 | Steps: 1552382
# DDQN Ep: 3430 | Score: 37.0 | Avg (100): 103.56 | Epsilon: 0.02 | Steps: 1557946
# DDQN Ep: 3440 | Score: 25.0 | Avg (100): 99.34 | Epsilon: 0.02 | Steps: 1563104
# DDQN Ep: 3450 | Score: 33.0 | Avg (100): 94.75 | Epsilon: 0.02 | Steps: 1567829
# DDQN Ep: 3460 | Score: 55.0 | Avg (100): 98.14 | Epsilon: 0.02 | Steps: 1574902
# DDQN Ep: 3470 | Score: 35.0 | Avg (100): 97.15 | Epsilon: 0.02 | Steps: 1580953
# DDQN Ep: 3480 | Score: 92.0 | Avg (100): 97.18 | Epsilon: 0.02 | Steps: 1586380
# DDQN Ep: 3490 | Score: 92.0 | Avg (100): 90.88 | Epsilon: 0.02 | Steps: 1592308
# DDQN Ep: 3500 | Score: 214.0 | Avg (100): 90.22 | Epsilon: 0.02 | Steps: 1597216
# DDQN Ep: 3510 | Score: 303.0 | Avg (100): 92.29 | Epsilon: 0.02 | Steps: 1603046
# DDQN Ep: 3520 | Score: 222.0 | Avg (100): 100.67 | Epsilon: 0.02 | Steps: 1610314
# DDQN Ep: 3530 | Score: 274.0 | Avg (100): 109.76 | Epsilon: 0.02 | Steps: 1617794
# DDQN Ep: 3540 | Score: 231.0 | Avg (100): 112.75 | Epsilon: 0.02 | Steps: 1623849
# DDQN Ep: 3550 | Score: 77.0 | Avg (100): 120.11 | Epsilon: 0.02 | Steps: 1630478
# DDQN Ep: 3560 | Score: 98.0 | Avg (100): 118.06 | Epsilon: 0.02 | Steps: 1636924
# DDQN Ep: 3570 | Score: 320.0 | Avg (100): 117.62 | Epsilon: 0.02 | Steps: 1643024
# DDQN Ep: 3580 | Score: 30.0 | Avg (100): 117.82 | Epsilon: 0.02 | Steps: 1649299
# DDQN Ep: 3590 | Score: 320.0 | Avg (100): 129.53 | Epsilon: 0.02 | Steps: 1657224
# DDQN Ep: 3600 | Score: 53.0 | Avg (100): 136.93 | Epsilon: 0.02 | Steps: 1664080
# DDQN Ep: 3610 | Score: 21.0 | Avg (100): 135.42 | Epsilon: 0.02 | Steps: 1669769
# DDQN Ep: 3620 | Score: 77.0 | Avg (100): 130.86 | Epsilon: 0.02 | Steps: 1676478
# DDQN Ep: 3630 | Score: 8.0 | Avg (100): 123.10 | Epsilon: 0.02 | Steps: 1682259
# DDQN Ep: 3640 | Score: 199.0 | Avg (100): 122.21 | Epsilon: 0.02 | Steps: 1688795
# DDQN Ep: 3650 | Score: 320.0 | Avg (100): 131.41 | Epsilon: 0.02 | Steps: 1696820
# DDQN Ep: 3660 | Score: 274.0 | Avg (100): 128.79 | Epsilon: 0.02 | Steps: 1702432
# DDQN Ep: 3670 | Score: 270.0 | Avg (100): 131.07 | Epsilon: 0.02 | Steps: 1708654
# DDQN Ep: 3680 | Score: 97.0 | Avg (100): 131.32 | Epsilon: 0.02 | Steps: 1715045
# DDQN Ep: 3690 | Score: 52.0 | Avg (100): 120.10 | Epsilon: 0.02 | Steps: 1722231
# DDQN Ep: 3700 | Score: 20.0 | Avg (100): 118.99 | Epsilon: 0.02 | Steps: 1729649
# DDQN Ep: 3710 | Score: 271.0 | Avg (100): 128.81 | Epsilon: 0.02 | Steps: 1736644
# DDQN Ep: 3720 | Score: 10.0 | Avg (100): 118.99 | Epsilon: 0.02 | Steps: 1740591
# DDQN Ep: 3730 | Score: 320.0 | Avg (100): 124.83 | Epsilon: 0.02 | Steps: 1747486
# DDQN Ep: 3740 | Score: 32.0 | Avg (100): 133.67 | Epsilon: 0.02 | Steps: 1754833
# DDQN Ep: 3750 | Score: 320.0 | Avg (100): 128.53 | Epsilon: 0.02 | Steps: 1761912
# DDQN Ep: 3760 | Score: 7.0 | Avg (100): 130.19 | Epsilon: 0.02 | Steps: 1768172
# DDQN Ep: 3770 | Score: 321.0 | Avg (100): 128.75 | Epsilon: 0.02 | Steps: 1774208
# DDQN Ep: 3780 | Score: 8.0 | Avg (100): 120.94 | Epsilon: 0.02 | Steps: 1777995
# DDQN Ep: 3790 | Score: 49.0 | Avg (100): 112.00 | Epsilon: 0.02 | Steps: 1780542
# DDQN Ep: 3800 | Score: 320.0 | Avg (100): 105.82 | Epsilon: 0.02 | Steps: 1785996
# DDQN Ep: 3810 | Score: 45.0 | Avg (100): 105.98 | Epsilon: 0.02 | Steps: 1793792
# DDQN Ep: 3820 | Score: 346.0 | Avg (100): 119.16 | Epsilon: 0.02 | Steps: 1800750
# DDQN Ep: 3830 | Score: 274.0 | Avg (100): 115.42 | Epsilon: 0.02 | Steps: 1806990
# DDQN Ep: 3840 | Score: 10.0 | Avg (100): 102.94 | Epsilon: 0.02 | Steps: 1811878
# DDQN Ep: 3850 | Score: 297.0 | Avg (100): 97.31 | Epsilon: 0.02 | Steps: 1817743
# DDQN Ep: 3860 | Score: 334.0 | Avg (100): 97.42 | Epsilon: 0.02 | Steps: 1824110
# DDQN Ep: 3870 | Score: 14.0 | Avg (100): 92.23 | Epsilon: 0.02 | Steps: 1829772
# DDQN Ep: 3880 | Score: 11.0 | Avg (100): 107.06 | Epsilon: 0.02 | Steps: 1836684
# DDQN Ep: 3890 | Score: 231.0 | Avg (100): 113.99 | Epsilon: 0.02 | Steps: 1842086
# DDQN Ep: 3900 | Score: 25.0 | Avg (100): 116.14 | Epsilon: 0.02 | Steps: 1847851
# DDQN Ep: 3910 | Score: 335.0 | Avg (100): 104.96 | Epsilon: 0.02 | Steps: 1852858
# DDQN Ep: 3920 | Score: 193.0 | Avg (100): 101.27 | Epsilon: 0.02 | Steps: 1859305
# DDQN Ep: 3930 | Score: 214.0 | Avg (100): 98.62 | Epsilon: 0.02 | Steps: 1865130
# DDQN Ep: 3940 | Score: 17.0 | Avg (100): 104.68 | Epsilon: 0.02 | Steps: 1871357
# DDQN Ep: 3950 | Score: 5.0 | Avg (100): 108.53 | Epsilon: 0.02 | Steps: 1877655
# DDQN Ep: 3960 | Score: 17.0 | Avg (100): 109.95 | Epsilon: 0.02 | Steps: 1883896
# DDQN Ep: 3970 | Score: 44.0 | Avg (100): 123.07 | Epsilon: 0.02 | Steps: 1891402
# DDQN Ep: 3980 | Score: 320.0 | Avg (100): 126.79 | Epsilon: 0.02 | Steps: 1899142
# DDQN Ep: 3990 | Score: 46.0 | Avg (100): 131.95 | Epsilon: 0.02 | Steps: 1905597
# DDQN Ep: 4000 | Score: 54.0 | Avg (100): 135.93 | Epsilon: 0.02 | Steps: 1911803
# DDQN Ep: 4010 | Score: 3.0 | Avg (100): 141.79 | Epsilon: 0.02 | Steps: 1918765
# DDQN Ep: 4020 | Score: 35.0 | Avg (100): 142.52 | Epsilon: 0.02 | Steps: 1924940
# DDQN Ep: 4030 | Score: 304.0 | Avg (100): 149.74 | Epsilon: 0.02 | Steps: 1932058
# DDQN Ep: 4040 | Score: 41.0 | Avg (100): 150.66 | Epsilon: 0.02 | Steps: 1938564
# DDQN Ep: 4050 | Score: 10.0 | Avg (100): 151.53 | Epsilon: 0.02 | Steps: 1945769
# DDQN Ep: 4060 | Score: 320.0 | Avg (100): 149.40 | Epsilon: 0.02 | Steps: 1952153
# DDQN Ep: 4070 | Score: 31.0 | Avg (100): 142.21 | Epsilon: 0.02 | Steps: 1958364
# DDQN Ep: 4080 | Score: 20.0 | Avg (100): 133.47 | Epsilon: 0.02 | Steps: 1964226
# DDQN Ep: 4090 | Score: 30.0 | Avg (100): 131.48 | Epsilon: 0.02 | Steps: 1969946
# DDQN Ep: 4100 | Score: 25.0 | Avg (100): 126.84 | Epsilon: 0.02 | Steps: 1975344
# DDQN Ep: 4110 | Score: 8.0 | Avg (100): 129.75 | Epsilon: 0.02 | Steps: 1982055
# DDQN Ep: 4120 | Score: 76.0 | Avg (100): 121.42 | Epsilon: 0.02 | Steps: 1987056
# DDQN Ep: 4130 | Score: 54.0 | Avg (100): 120.35 | Epsilon: 0.02 | Steps: 1993949
# DDQN Ep: 4140 | Score: 24.0 | Avg (100): 110.29 | Epsilon: 0.02 | Steps: 1998529
# DDQN Ep: 4150 | Score: 40.0 | Avg (100): 102.27 | Epsilon: 0.02 | Steps: 2004271
# DDQN Ep: 4160 | Score: 69.0 | Avg (100): 99.50 | Epsilon: 0.02 | Steps: 2009914
# DDQN Ep: 4170 | Score: 43.0 | Avg (100): 97.07 | Epsilon: 0.02 | Steps: 2015830
# DDQN Ep: 4180 | Score: 320.0 | Avg (100): 101.39 | Epsilon: 0.02 | Steps: 2023211
# DDQN Ep: 4190 | Score: 28.0 | Avg (100): 98.88 | Epsilon: 0.02 | Steps: 2028513
# DDQN Ep: 4200 | Score: 248.0 | Avg (100): 99.76 | Epsilon: 0.02 | Steps: 2033998
# DDQN Ep: 4210 | Score: 55.0 | Avg (100): 90.88 | Epsilon: 0.02 | Steps: 2038888
# DDQN Ep: 4220 | Score: 25.0 | Avg (100): 95.91 | Epsilon: 0.02 | Steps: 2044668
# DDQN Ep: 4230 | Score: 320.0 | Avg (100): 94.78 | Epsilon: 0.02 | Steps: 2051543
# DDQN Ep: 4240 | Score: 36.0 | Avg (100): 103.75 | Epsilon: 0.02 | Steps: 2057560
# DDQN Ep: 4250 | Score: 36.0 | Avg (100): 104.70 | Epsilon: 0.02 | Steps: 2063292
# DDQN Ep: 4260 | Score: 320.0 | Avg (100): 108.75 | Epsilon: 0.02 | Steps: 2069822
# DDQN Ep: 4270 | Score: 15.0 | Avg (100): 105.25 | Epsilon: 0.02 | Steps: 2075029
# DDQN Ep: 4280 | Score: 334.0 | Avg (100): 111.28 | Epsilon: 0.02 | Steps: 2083090
# DDQN Ep: 4290 | Score: 3.0 | Avg (100): 111.73 | Epsilon: 0.02 | Steps: 2088404
# DDQN Ep: 4300 | Score: 27.0 | Avg (100): 113.12 | Epsilon: 0.02 | Steps: 2094471
# DDQN Ep: 4310 | Score: 22.0 | Avg (100): 119.07 | Epsilon: 0.02 | Steps: 2100531
# DDQN Ep: 4320 | Score: 21.0 | Avg (100): 116.51 | Epsilon: 0.02 | Steps: 2105779
# DDQN Ep: 4330 | Score: 3.0 | Avg (100): 108.72 | Epsilon: 0.02 | Steps: 2110670
# DDQN Ep: 4340 | Score: 42.0 | Avg (100): 108.70 | Epsilon: 0.02 | Steps: 2116876
# DDQN Ep: 4350 | Score: 16.0 | Avg (100): 114.26 | Epsilon: 0.02 | Steps: 2123479
# DDQN Ep: 4360 | Score: 97.0 | Avg (100): 113.80 | Epsilon: 0.02 | Steps: 2129910
# DDQN Ep: 4370 | Score: 58.0 | Avg (100): 115.39 | Epsilon: 0.02 | Steps: 2135345
# DDQN Ep: 4380 | Score: 335.0 | Avg (100): 109.05 | Epsilon: 0.02 | Steps: 2142046
# DDQN Ep: 4390 | Score: 53.0 | Avg (100): 112.59 | Epsilon: 0.02 | Steps: 2148713
# DDQN Ep: 4400 | Score: 29.0 | Avg (100): 111.99 | Epsilon: 0.02 | Steps: 2155460
# DDQN Ep: 4410 | Score: 35.0 | Avg (100): 107.25 | Epsilon: 0.02 | Steps: 2161270
# DDQN Ep: 4420 | Score: 35.0 | Avg (100): 115.84 | Epsilon: 0.02 | Steps: 2169024
# DDQN Ep: 4430 | Score: 17.0 | Avg (100): 113.25 | Epsilon: 0.02 | Steps: 2174922
# DDQN Ep: 4440 | Score: 29.0 | Avg (100): 106.78 | Epsilon: 0.02 | Steps: 2180061
# DDQN Ep: 4450 | Score: 93.0 | Avg (100): 108.44 | Epsilon: 0.02 | Steps: 2187200
# DDQN Ep: 4460 | Score: 314.0 | Avg (100): 107.42 | Epsilon: 0.02 | Steps: 2193325
# DDQN Ep: 4470 | Score: 46.0 | Avg (100): 109.86 | Epsilon: 0.02 | Steps: 2199584
# DDQN Ep: 4480 | Score: 35.0 | Avg (100): 104.20 | Epsilon: 0.02 | Steps: 2205141
# DDQN Ep: 4490 | Score: 20.0 | Avg (100): 96.01 | Epsilon: 0.02 | Steps: 2209655
# DDQN Ep: 4500 | Score: 45.0 | Avg (100): 92.50 | Epsilon: 0.02 | Steps: 2215052
# DDQN Ep: 4510 | Score: 320.0 | Avg (100): 94.66 | Epsilon: 0.02 | Steps: 2220708
# DDQN Ep: 4520 | Score: 320.0 | Avg (100): 93.19 | Epsilon: 0.02 | Steps: 2227199
# DDQN Ep: 4530 | Score: 83.0 | Avg (100): 97.18 | Epsilon: 0.02 | Steps: 2233916
# DDQN Ep: 4540 | Score: 35.0 | Avg (100): 102.34 | Epsilon: 0.02 | Steps: 2240302
# DDQN Ep: 4550 | Score: 3.0 | Avg (100): 91.95 | Epsilon: 0.02 | Steps: 2244814
# DDQN Ep: 4560 | Score: 62.0 | Avg (100): 90.17 | Epsilon: 0.02 | Steps: 2251182
# DDQN Ep: 4570 | Score: 320.0 | Avg (100): 96.85 | Epsilon: 0.02 | Steps: 2258858
# DDQN Ep: 4580 | Score: 97.0 | Avg (100): 94.68 | Epsilon: 0.02 | Steps: 2264173
# DDQN Ep: 4590 | Score: 35.0 | Avg (100): 103.97 | Epsilon: 0.02 | Steps: 2270238
# DDQN Ep: 4600 | Score: 38.0 | Avg (100): 107.34 | Epsilon: 0.02 | Steps: 2276249
# DDQN Ep: 4610 | Score: 297.0 | Avg (100): 109.75 | Epsilon: 0.02 | Steps: 2282665
# DDQN Ep: 4620 | Score: 54.0 | Avg (100): 104.07 | Epsilon: 0.02 | Steps: 2287892
# DDQN Ep: 4630 | Score: 33.0 | Avg (100): 107.04 | Epsilon: 0.02 | Steps: 2294367
# DDQN Ep: 4640 | Score: 61.0 | Avg (100): 101.23 | Epsilon: 0.02 | Steps: 2300266
# DDQN Ep: 4650 | Score: 31.0 | Avg (100): 113.81 | Epsilon: 0.02 | Steps: 2307938
# DDQN Ep: 4660 | Score: 320.0 | Avg (100): 112.49 | Epsilon: 0.02 | Steps: 2313561
# DDQN Ep: 4670 | Score: 320.0 | Avg (100): 109.96 | Epsilon: 0.02 | Steps: 2320296
# DDQN Ep: 4680 | Score: 320.0 | Avg (100): 125.17 | Epsilon: 0.02 | Steps: 2328392
# DDQN Ep: 4690 | Score: 40.0 | Avg (100): 129.39 | Epsilon: 0.02 | Steps: 2335725
# DDQN Ep: 4700 | Score: 54.0 | Avg (100): 139.03 | Epsilon: 0.02 | Steps: 2343474
# DDQN Ep: 4710 | Score: 321.0 | Avg (100): 135.87 | Epsilon: 0.02 | Steps: 2349011
# DDQN Ep: 4720 | Score: 32.0 | Avg (100): 136.76 | Epsilon: 0.02 | Steps: 2354734
# DDQN Ep: 4730 | Score: 5.0 | Avg (100): 134.18 | Epsilon: 0.02 | Steps: 2360387
# DDQN Ep: 4740 | Score: 29.0 | Avg (100): 137.93 | Epsilon: 0.02 | Steps: 2366090
# DDQN Ep: 4750 | Score: 33.0 | Avg (100): 122.52 | Epsilon: 0.02 | Steps: 2369948
# DDQN Ep: 4760 | Score: 46.0 | Avg (100): 130.55 | Epsilon: 0.02 | Steps: 2376973
# DDQN Ep: 4770 | Score: 36.0 | Avg (100): 125.06 | Epsilon: 0.02 | Steps: 2382696
# DDQN Ep: 4780 | Score: 36.0 | Avg (100): 110.82 | Epsilon: 0.02 | Steps: 2388556
# DDQN Ep: 4790 | Score: 5.0 | Avg (100): 100.61 | Epsilon: 0.02 | Steps: 2393980
# DDQN Ep: 4800 | Score: 90.0 | Avg (100): 92.92 | Epsilon: 0.02 | Steps: 2400734
# DDQN Ep: 4810 | Score: 320.0 | Avg (100): 99.13 | Epsilon: 0.02 | Steps: 2407398
# DDQN Ep: 4820 | Score: 69.0 | Avg (100): 96.60 | Epsilon: 0.02 | Steps: 2412277
# DDQN Ep: 4830 | Score: 320.0 | Avg (100): 99.71 | Epsilon: 0.02 | Steps: 2418181
# DDQN Ep: 4840 | Score: 13.0 | Avg (100): 97.43 | Epsilon: 0.02 | Steps: 2424220
# DDQN Ep: 4850 | Score: 45.0 | Avg (100): 108.77 | Epsilon: 0.02 | Steps: 2431295
# DDQN Ep: 4860 | Score: 320.0 | Avg (100): 107.85 | Epsilon: 0.02 | Steps: 2438311
# DDQN Ep: 4870 | Score: 274.0 | Avg (100): 115.61 | Epsilon: 0.02 | Steps: 2445589
# DDQN Ep: 4880 | Score: 33.0 | Avg (100): 111.40 | Epsilon: 0.02 | Steps: 2450838
# DDQN Ep: 4890 | Score: 58.0 | Avg (100): 115.26 | Epsilon: 0.02 | Steps: 2457489
# DDQN Ep: 4900 | Score: 21.0 | Avg (100): 106.83 | Epsilon: 0.02 | Steps: 2462633
# DDQN Ep: 4910 | Score: 214.0 | Avg (100): 103.35 | Epsilon: 0.02 | Steps: 2468622
# DDQN Ep: 4920 | Score: 31.0 | Avg (100): 110.98 | Epsilon: 0.02 | Steps: 2475282
# DDQN Ep: 4930 | Score: 31.0 | Avg (100): 106.32 | Epsilon: 0.02 | Steps: 2480427
# DDQN Ep: 4940 | Score: 33.0 | Avg (100): 110.83 | Epsilon: 0.02 | Steps: 2486455
# DDQN Ep: 4950 | Score: 321.0 | Avg (100): 102.25 | Epsilon: 0.02 | Steps: 2490910
# DDQN Ep: 4960 | Score: 54.0 | Avg (100): 94.92 | Epsilon: 0.02 | Steps: 2496943
# DDQN Ep: 4970 | Score: 97.0 | Avg (100): 84.36 | Epsilon: 0.02 | Steps: 2502650
# DDQN Ep: 4980 | Score: 70.0 | Avg (100): 89.25 | Epsilon: 0.02 | Steps: 2508182
# DDQN Ep: 4990 | Score: 45.0 | Avg (100): 86.49 | Epsilon: 0.02 | Steps: 2513953
# Double DQN Training Finished.

# %%
# --- CELL 9: VISUALIZATION & METRICS ---

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

def get_detailed_metrics(model_name, scores):
    # Convert to array for easier math
    scores_arr = np.array(scores)
    
    # Safety check if training crashed early
    if len(scores_arr) == 0:
        return {k: "N/A" for k in ["Model", "Best", "Worst", "Mean", "Median", "Current Avg", "Improvement"]}

    # 1. Best & Worst (with Episode #)
    best_idx = np.argmax(scores_arr)
    worst_idx = np.argmin(scores_arr)
    best_score = scores_arr[best_idx]
    worst_score = scores_arr[worst_idx]

    # 2. Central Tendencies
    lifetime_mean = np.mean(scores_arr)
    median_score = np.median(scores_arr)

    # 3. Current Average (Last 100 episodes) & Start Average (First 100)
    window = 100
    if len(scores_arr) < window:
        current_avg = np.mean(scores_arr)
        start_avg = np.mean(scores_arr)
    else:
        current_avg = np.mean(scores_arr[-window:])
        start_avg = np.mean(scores_arr[:window])

    # 4. Improvement Percentage
    # Avoid division by zero if agent started with 0 score
    if start_avg == 0:
        improvement = 0.0
    else:
        improvement = ((current_avg - start_avg) / start_avg) * 100

    return {
        "Model": model_name,
        "Best Score": f"{best_score:.2f} (Ep {best_idx})",
        "Worst Score": f"{worst_score:.2f} (Ep {worst_idx})",
        "Lifetime Mean": f"{lifetime_mean:.2f}",
        "Median Score": f"{median_score:.2f}",
        "Current Avg (Last 100)": f"{current_avg:.2f}",
        "Improvement %": f"{improvement:.1f}%"
    }

# --- A. GENERATE TABLE ---
metrics_dqn = get_detailed_metrics("Standard DQN", rewards_history)
metrics_ddqn = get_detailed_metrics("Double DQN", ddqn_scores)

df = pd.DataFrame([metrics_dqn, metrics_ddqn])
df.set_index("Model", inplace=True)

print("--- PERFORMANCE STATISTICS ---")
display(df) # Logic for Jupyter Notebook display

# --- B. GENERATE GRAPH ---
plt.figure(figsize=(15, 6))

# Helper for moving average (smoothing)
def moving_average(data, window_size=50):
    return pd.Series(data).rolling(window=window_size, min_periods=1).mean()

# Plot Standard DQN
plt.plot(rewards_history, color='red', alpha=0.3, linewidth=1, label='DQN (Raw)')
plt.plot(moving_average(rewards_history), color='darkred', linewidth=2, label='DQN (MA-50)')

# Plot Double DQN
plt.plot(ddqn_scores, color='blue', alpha=0.3, linewidth=1, label='DDQN (Raw)')
plt.plot(moving_average(ddqn_scores), color='darkblue', linewidth=2, label='DDQN (MA-50)')

plt.title("Training Comparison: Standard DQN vs Double DQN (Breakout-v5)", fontsize=14)
plt.xlabel("Episode")
plt.ylabel("Score")
plt.legend()
plt.grid(True, alpha=0.2)

plt.show()
# Out:
# --- PERFORMANCE STATISTICS ---
#                     Best Score  Worst Score Lifetime Mean Median Score  \
# Model
# Standard DQN  403.00 (Ep 3576)  0.00 (Ep 1)        116.65        26.00
# Double DQN    355.00 (Ep 4277)  0.00 (Ep 0)         63.80        28.00
#
#              Current Avg (Last 100) Improvement %
# Model
# Standard DQN                 209.71      20663.4%
# Double DQN                    87.04       8517.8%
